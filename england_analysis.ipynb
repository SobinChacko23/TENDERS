# %%
import pandas as pd

# Load data from a CSV file (Replace 'data.csv' with your actual file name)
df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\ENGLAND\ENGLAND_CONTRACTS.csv")

# Display the first few rows to understand the data structure
print(df.head())
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_13380\1980216054.py:4: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\ENGLAND\ENGLAND_CONTRACTS.csv")
#   Notice Identifier Notice Type                      Organisation Name  \
# 0         766329433    Contract                                    YPO
# 1         458333305    Contract                Swindon Borough Council
# 2          MT154529    Contract  Centre for Process Innovation Limited
# 3      BIP144373589    Contract          Guys and St Thomas' NHS Trust
# 4      BIP142531502    Contract               Procurement Lincolnshire
#
#     Status             Published Date  \
# 0   Closed  2015-05-13T14:26:02+01:00
# 1   Closed  2015-05-11T14:11:38+01:00
# 2  Awarded  2015-05-25T08:40:00+01:00
# 3   Closed  2015-05-19T14:15:05+01:00
# 4   Closed  2015-05-01T11:30:03+01:00
#
#                                                Title  \
# 0  YPO - 000615 Whiteboards, Noticeboards, Displa...
# 1  Gift Shop Suppliers for STEAM - Museum of the ...
# 2                         MFD Supply and Maintenance
# 3    GB-London: Minerva House Digital Media Solution
# 4     GB-Lincoln: Website, CMS and Intranet Services
#
#                                          Description  Nationwide Postcode  \
# 0  YPO - 000615 Whiteboards, Noticeboards, Displa...         NaN      NaN
# 1  Swindon Borough Council is seeking potential s...         NaN      NaN
# 2  CPI is seeking to establish a single supplier ...         NaN      NaN
# 3  Requirement for the provision of audio visual ...         NaN      NaN
# 4  Requirements for replacement CMS, Website and ...         NaN      NaN
#
#           Region  ... Value High Awarded Date Awarded Value  \
# 0     Any region  ...  7000000.0          NaN           NaN
# 1     South West  ...   120000.0          NaN           NaN
# 2     North East  ...        NaN   22/05/2015      170000.0
# 3         London  ...   100000.0          NaN           NaN
# 4  East Midlands  ...    50000.0          NaN           NaN
#
#   Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 0                                                NaN
# 1                                                NaN
# 2  [Complete Office Solutions (UK) Limited|Daught...
# 3                                                NaN
# 4                                                NaN
#
#   Supplier's contact name Contract start date Contract end date  \
# 0                     NaN                 NaN               NaN
# 1                     NaN                 NaN               NaN
# 2                     NaN          22/05/2015        22/05/2018
# 3                     NaN                 NaN               NaN
# 4                     NaN                 NaN               NaN
#
#   OJEU Procedure Type Accelerated Justification Closing Time
# 0                                           NaN          NaN
# 1                                           NaN          NaN
# 2               Open                        NaN          NaN
# 3               Open                        NaN          NaN
# 4               Open                        NaN          NaN
#
# [5 rows x 43 columns]

# %%
# Convert 'Published Date' and 'Awarded Date' to datetime, ensuring UTC timezone and proper format parsing
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)
df['Awarded Date'] = pd.to_datetime(df['Awarded Date'], errors='coerce', utc=True)

# Filter for contracts where 'Status' is 'Awarded'
awarded_df = df[df['Status'] == 'Awarded']

# Fill missing 'Awarded Date' with 'Published Date' where 'Status' is 'Awarded'
awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# Filter for data from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Extract year and month for grouping
df['Published Year'] = df['Published Date'].dt.year
df['Published Month'] = df['Published Date'].dt.month
awarded_df['Awarded Year'] = awarded_df['Awarded Date'].dt.year
awarded_df['Awarded Month'] = awarded_df['Awarded Date'].dt.month

# Group and count the number of contracts published each month
published_counts = df.groupby(['Published Year', 'Published Month']).size().reset_index(name='Published Count')

# Group and count the number of contracts awarded each month
awarded_counts = awarded_df.groupby(['Awarded Year', 'Awarded Month']).size().reset_index(name='Awarded Count')

# Plotting the results
years = sorted(published_counts['Published Year'].unique())

for year in years:
    plt.figure(figsize=(10, 6))

    # Filter data for the current year
    published_data = published_counts[published_counts['Published Year'] == year]
    awarded_data = awarded_counts[awarded_counts['Awarded Year'] == year]
    
    # Plotting
    plt.plot(published_data['Published Month'], published_data['Published Count'], marker='o', label='Published')
    plt.plot(awarded_data['Awarded Month'], awarded_data['Awarded Count'], marker='x', label='Awarded')
    
    # Labels and title
    plt.xlabel('Month')
    plt.ylabel('Number of Contracts')
    plt.title(f'Contracts Published and Awarded in {year}')
    plt.legend()
    plt.grid(True)
    
    # Show the plot for the current year
    plt.show()
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_13380\51448626.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Awarded Date'] = pd.to_datetime(df['Awarded Date'], errors='coerce', utc=True)
# C:\Users\sobin\AppData\Local\Temp\ipykernel_13380\51448626.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# %%
df.isnull().sum()
# Out:
# Notice Identifier                                                29
# Notice Type                                                       0
# Organisation Name                                                 6
# Status                                                            0
# Published Date                                                    0
# Title                                                             0
# Description                                                      32
# Nationwide                                                    83357
# Postcode                                                      54663
# Region                                                        11796
# Cpv Codes                                                         0
# Contact Name                                                  23225
# Contact Email                                                     1
# Contact Address 1                                                 5
# Contact Address 2                                             55382
# Contact Town                                                      6
# Contact Postcode                                                  1
# Contact Country                                                   0
# Contact Telephone                                             39383
# Contact Website                                               59312
# Attachments                                                   66225
# Links                                                         65890
# Additional Text                                               71751
# Start Date                                                     1122
# End Date                                                       1122
# Closing Date                                                     49
# Is sub-contract                                                   0
# Parent Reference                                              81572
# Suitable for SME                                                133
# Suitable for VCO                                                133
# Supply Chain                                                      0
# OJEU Contract Type                                             2320
# Value Low                                                       992
# Value High                                                    52484
# Awarded Date                                                  17339
# Awarded Value                                                 17328
# Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]    17328
# Supplier's contact name                                       83617
# Contract start date                                           17329
# Contract end date                                             17329
# OJEU Procedure Type                                               0
# Accelerated Justification                                     83582
# Closing Time                                                  33028
# Published Year                                                    0
# Published Month                                                   0
# dtype: int64

# %%
# Example strategy: Fill missing numeric values with 0 and categorical with 'Unknown'
df['Postcode'] = df['Postcode'].fillna('Unknown')
df['Value Low'] = df['Value Low'].fillna(0)
df['Value High'] = df['Value High'].fillna(0)

# %%
# Drop columns with excessive missing data if necessary (e.g., more than 50% missing)
df = df.dropna(thresh=len(df) * 0.5, axis=1)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Basic statistics
print(df.describe())

# Number of tenders by region
tenders_by_region = df['Region'].value_counts()
print("Tenders by Region:\n", tenders_by_region)

# Distribution of contract values
df['Value Low'] = pd.to_numeric(df['Value Low'], errors='coerce')
df['Value High'] = pd.to_numeric(df['Value High'], errors='coerce')

df[['Value Low', 'Value High']].hist(bins=50)
plt.show()
# Out:
#           Value Low    Value High  Awarded Value  Published Year  \
# count  8.361700e+04  8.361700e+04   6.628900e+04    83617.000000
# mean   3.222293e+07  5.686776e+06   6.641772e+06     2020.582358
# std    6.921319e+09  3.726599e+08   2.531596e+08        2.475480
# min    0.000000e+00  0.000000e+00   0.000000e+00     2015.000000
# 25%    1.970000e+04  0.000000e+00   3.600000e+04     2019.000000
# 50%    6.329700e+04  0.000000e+00   8.800000e+04     2021.000000
# 75%    2.325025e+05  5.000000e+04   3.000000e+05     2023.000000
# max    2.000000e+12  1.020000e+11   5.100000e+10     2024.000000
#
#        Published Month
# count     83617.000000
# mean          6.188730
# std           3.386395
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Tenders by Region:
#  Region
# Any region                                                                                                                                 20204
# London                                                                                                                                      7689
# England                                                                                                                                     5607
# South West                                                                                                                                  5519
# United Kingdom                                                                                                                              5406
#                                                                                                                                            ...
# North West,East Midlands,London                                                                                                                1
# West Midlands,London,South East,South West,Wales                                                                                               1
# North East,Yorkshire and The Humber,North West,East Midlands,West Midlands,East of England,South East,South West,London,Channel Islands        1
# London,North West,Yorkshire and The Humber                                                                                                     1
# North East,North West,East Midlands,West Midlands,East of England,London,Channel Islands                                                       1
# Name: count, Length: 269, dtype: int64

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import numpy as np

# Convert the 'Published Date' column to datetime, handling mixed time zones
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Drop rows where 'Published Date' could not be converted
df = df.dropna(subset=['Published Date'])

# Extract the year from the 'Published Date' column
df['Year'] = df['Published Date'].dt.year

# Filter data to include only contracts from 2015 onwards
df = df[df['Year'] >= 2015]

# Group data by year and count the number of tenders per year
annual_data = df.groupby('Year').size()

# Adjust the count for 2024 based on the number of months available (8/12)
if 2024 in annual_data.index:
    annual_data[2024] = annual_data[2024] * (12 / 8)

# Find optimal ARIMA order
model = auto_arima(annual_data, seasonal=False)
model_fit = model.fit(annual_data)

# Predict the next 5 years
forecast, conf_int = model_fit.predict(n_periods=5, return_conf_int=True)

# Create forecast years
forecast_years = np.arange(annual_data.index[-1] + 1, annual_data.index[-1] + 6)

# Plot the historical data and the forecast
plt.figure(figsize=(12, 8))
plt.plot(annual_data.index, annual_data, label='Historical Data', color='steelblue', marker='o', linestyle='-')
plt.plot(forecast_years, forecast, label='Forecast', color='darkorange', linestyle='--', marker='x')

# Add confidence intervals
plt.fill_between(forecast_years, conf_int[:, 0], conf_int[:, 1], color='darkorange', alpha=0.3)

# Annotations and labels
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Tenders', fontsize=14)
plt.title('Forecast of Number of Tenders from 2015 for the Next 5 Years', fontsize=16)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(np.arange(min(annual_data.index), max(forecast_years) + 1, 1), rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_13380\411256583.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13342.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   annual_data[2024] = annual_data[2024] * (12 / 8)
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd

# Convert 'Start Date' and 'End Date' to datetime, handling any errors
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', utc=True)
df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)

# Ensure 'Status' column is of type string
df['Status'] = df['Status'].astype(str)

# Count frameworks by type and region
framework_by_region = df.groupby(['Region', 'OJEU Contract Type']).size().unstack(fill_value=0)
print("Frameworks by Region and Type:\n", framework_by_region)

# For live and upcoming frameworks, filter based on date and status
current_year = pd.Timestamp.now().year

# Filter for live frameworks
live_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) & 
    (df['End Date'].notna()) &
    (df['Start Date'].dt.year <= current_year) &
    (df['End Date'].dt.year >= current_year)
]

# Filter for upcoming frameworks
upcoming_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) &
    (df['Start Date'].dt.year > current_year)
]

print("Live Frameworks:\n", live_frameworks)
print("Upcoming Frameworks:\n", upcoming_frameworks)
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_13380\1426416616.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)
# Frameworks by Region and Type:
#  OJEU Contract Type                                  NotApplicable  \
# Region
# Any region                                                   1092
# Any region,East Midlands,East of England                        0
# Any region,East Midlands,West Midlands                          0
# Any region,East of England                                      0
# Any region,London                                               0
# ...                                                           ...
# Yorkshire and The Humber,United Kingdom                         6
# Yorkshire and The Humber,United Kingdom,Any region              1
# Yorkshire and The Humber,West Midlands                          0
# Yorkshire and The Humber,West Midlands,London                   0
# Yorkshire and The Humber,West Midlands,South We...              1
#
# OJEU Contract Type                                  NotSpecified  Products  \
# Region
# Any region                                                   231      4786
# Any region,East Midlands,East of England                       0         0
# Any region,East Midlands,West Midlands                         0         0
# Any region,East of England                                     0         1
# Any region,London                                              0         3
# ...                                                          ...       ...
# Yorkshire and The Humber,United Kingdom                        0         2
# Yorkshire and The Humber,United Kingdom,Any region             0         0
# Yorkshire and The Humber,West Midlands                         0         0
# Yorkshire and The Humber,West Midlands,London                  0         1
# Yorkshire and The Humber,West Midlands,South We...             0         0
#
# OJEU Contract Type                                  Services  Works
# Region
# Any region                                             13047    532
# Any region,East Midlands,East of England                   1      0
# Any region,East Midlands,West Midlands                     3      0
# Any region,East of England                                 2      0
# Any region,London                                         37      0
# ...                                                      ...    ...
# Yorkshire and The Humber,United Kingdom                   13      0
# Yorkshire and The Humber,United Kingdom,Any region         0      0
# Yorkshire and The Humber,West Midlands                     7      0
# Yorkshire and The Humber,West Midlands,London              1      0
# Yorkshire and The Humber,West Midlands,South We...         0      0
#
# [261 rows x 5 columns]
# Live Frameworks:
#                     Notice Identifier Notice Type  \
# 18238                         MMU678    Contract
# 28732  NPSBARNS001-DN506130-21478015    Pipeline
# 34784  NPSBARNS001-DN536468-59820066    Pipeline
# 39844                         RM6235    Contract
# 63373                         MMU678    Contract
# ...                              ...         ...
# 77220          20240726180746-103298    Contract
# 77225    CHEAST001-DN731579-62134358    Contract
# 77283          tender_455106/1383974    Contract
# 77285          tender_455106/1383999    Contract
# 77310                      ATCIT2024    Contract
#
#                            Organisation Name Status            Published Date  \
# 18238     Manchester Metropolitan University   Open 2019-09-12 11:22:36+00:00
# 28732  Barnsley Metropolitan Borough Council   Open 2020-11-02 16:19:16+00:00
# 34784  Barnsley Metropolitan Borough Council   Open 2021-04-06 13:21:40+00:00
# 39844               Crown Commercial Service   Open 2021-09-10 07:44:22+00:00
# 63373     Manchester Metropolitan University   Open 2019-09-12 11:22:36+00:00
# ...                                      ...    ...                       ...
# 77220       East Riding of Yorkshire Council   Open 2024-07-26 17:07:51+00:00
# 77225          Cheshire East Borough Council   Open 2024-07-26 15:15:18+00:00
# 77283       ECL The Care & Wellbeing Company   Open 2024-07-24 14:47:30+00:00
# 77285       ECL The Care & Wellbeing Company   Open 2024-07-16 12:31:31+00:00
# 77310                  Amersham Town Council   Open 2024-07-23 13:11:38+00:00
#
#                                                    Title  \
# 18238      DPS for Testing Services and Resources CLOSED
# 28732                                      Mail Inserter
# 34784                   A542_Triscan_Odyssey Fuel System
# 39844              Space Enabled and Geospacial Services
# 63373      DPS for Testing Services and Resources CLOSED
# ...                                                  ...
# 77220  Strategic partner to co-design and support the...
# 77225    IT Health Checks and Cyber Security Consultancy
# 77283  0053 - Digtial Care & Client Management Soluti...
# 77285  0053 - Digtial Care & Client Management Soluti...
# 77310                               Supply of IT Support
#
#                                              Description Postcode  \
# 18238  Manchester Metropolitan University ("the Unive...   M156BH
# 28732  Purchase of Mail Inserter and Managed Service ...  Unknown
# 34784  To consolidate the contracts in the management...  Unknown
# 39844  Crown Commercial Service (CCS) as the Authorit...  Unknown
# 63373  Manchester Metropolitan University ("the Unive...   M156BH
# ...                                                  ...      ...
# 77220  The East Riding of Yorkshire Council (ERYC) ha...  Unknown
# 77225                                  ICT Health Checks  Unknown
# 77283  ECL is seeking a digital care and client manag...  CM1 1QH
# 77285  ECL is seeking a digital care and client manag...  CM1 1QH
# 77310  IT Support Services for a Town Council, with e...   hp70db
#
#                          Region  \
# 18238                Any region
# 28732                   England
# 34784            United Kingdom
# 39844            United Kingdom
# 63373                Any region
# ...                         ...
# 77220  Yorkshire and The Humber
# 77225                   England
# 77283           East of England
# 77285           East of England
# 77310                       NaN
#
#                                                Cpv Codes  ... Awarded Date  \
# 18238      72226000 72820000 72254100 72254000 72800000   ...          NaT
# 28732                                          30131000   ...          NaT
# 34784                                 48000000 72000000   ...          NaT
# 39844  32210000 32412100 32510000 32530000 38115100 3...  ...          NaT
# 63373      72226000 72820000 72254100 72254000 72800000   ...          NaT
# ...                                                  ...  ...          ...
# 77220                                          72000000   ...          NaT
# 77225                                          72000000   ...          NaT
# 77283                                          48000000   ...          NaT
# 77285                                          48000000   ...          NaT
# 77310                                          72000000   ...          NaT
#
#       Awarded Value  \
# 18238           NaN
# 28732           NaN
# 34784           NaN
# 39844           NaN
# 63373           NaN
# ...             ...
# 77220           NaN
# 77225           NaN
# 77283           NaN
# 77285           NaN
# 77310           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 18238                                                NaN
# 28732                                                NaN
# 34784                                                NaN
# 39844                                                NaN
# 63373                                                NaN
# ...                                                  ...
# 77220                                                NaN
# 77225                                                NaN
# 77283                                                NaN
# 77285                                                NaN
# 77310                                                NaN
#
#       Contract start date Contract end date           OJEU Procedure Type  \
# 18238                 NaN               NaN                     OpenOJEU
# 28732                 NaN               NaN
# 34784                 NaN               NaN
# 39844                 NaN               NaN               RestrictedOJEU
# 63373                 NaN               NaN                     OpenOJEU
# ...                   ...               ...                           ...
# 77220                 NaN               NaN                         Open
# 77225                 NaN               NaN                  OpenNonOJEU
# 77283                 NaN               NaN                     OpenOJEU
# 77285                 NaN               NaN                     OpenOJEU
# 77310                 NaN               NaN  CompetitiveQuotationNonOJEU
#
#       Closing Time Published Year Published Month  Year
# 18238        12:00           2019               9  2019
# 28732          NaN           2020              11  2020
# 34784          NaN           2021               4  2021
# 39844        11:59           2021               9  2021
# 63373        12:00           2019               9  2019
# ...            ...            ...             ...   ...
# 77220        12:00           2024               7  2024
# 77225        12:00           2024               7  2024
# 77283        12:00           2024               7  2024
# 77285        12:00           2024               7  2024
# 77310        14:00           2024               7  2024
#
# [84 rows x 37 columns]
# Upcoming Frameworks:
#                                         Notice Identifier Notice Type  \
# 22329                           YPO001-DN433526-71875119    Contract
# 23378                                             RM6213    Contract
# 34279                           YPO001-DN517178-18851510    Contract
# 38897                                             RM6124    Contract
# 42004                                             RM6126    Contract
# ...                                                  ...         ...
# 77058           Haringey Procurement - Public Protection    Contract
# 77064  Website Development, Hosting, Support & Mainte...    Contract
# 77141                         CF-0335800D8d000003VQwdEAG    Contract
# 77235                                IT-368-18023-CD1433    Contract
# 78744                                      CIMPLE-237688    Contract
#
#                                Organisation Name Status  \
# 22329                                        YPO   Open
# 23378                   Crown Commercial Service   Open
# 34279                                        YPO   Open
# 38897                   Crown Commercial Service   Open
# 42004                   Crown Commercial Service   Open
# ...                                          ...    ...
# 77058                           Haringey Council   Open
# 77064                     Dunstable Town Council   Open
# 77141                                      DEFRA   Open
# 77235                     Suffolk County Council   Open
# 78744  Bishop Wilkinson Catholic Education Trust   Open
#
#                  Published Date  \
# 22329 2020-01-28 15:13:55+00:00
# 23378 2020-04-10 12:28:04+00:00
# 34279 2021-04-08 08:23:59+00:00
# 38897 2021-08-05 14:19:50+00:00
# 42004 2021-11-03 10:20:06+00:00
# ...                         ...
# 77058 2024-08-05 07:38:05+00:00
# 77064 2024-08-02 15:33:58+00:00
# 77141 2024-07-31 14:56:41+00:00
# 77235 2024-07-26 11:52:00+00:00
# 78744 2022-05-09 11:03:51+00:00
#
#                                                    Title  \
# 22329  YPO - 000999 Training for The Emergency Servic...
# 23378    Vehicle Charging Infrastructure Solutions (DPS)
# 34279      YPO - 001056 Metering and Meter Data Services
# 38897                         Communications Marketplace
# 42004                          Research and Insights DPS
# ...                                                  ...
# 77058              Provision of Public Protection System
# 77064  Website Development, Hosting, Support & Mainte...
# 77141     FCP: Rural Payments Service Continuity Project
# 77235  Framlingham Sir Robert Hitcham's CEVAP School ...
# 78744  A DPS for sustainable and ethically sourced go...
#
#                                              Description  Postcode  \
# 22329  YPO are looking for Suppliers to be appointed ...   Unknown
# 23378  CCS has a dynamic purchasing system for Vehicl...   Unknown
# 34279  YPO are looking for Suppliers to be appointed ...   Unknown
# 38897  The Communications Marketplace DPS Agreement w...   Unknown
# 42004  Crown Commercial Service (CCS) as the authorit...   Unknown
# ...                                                  ...       ...
# 77058  To procure a software solution that allows Har...   Unknown
# 77064  Dunstable Town Council is seeking from supplie...   LU6 1NF
# 77141  The procurement documents are available for un...  SW1P 4DF
# 77235  Suffolk County Council are currently out to te...   IP1 2BX
# 78744  Bishop Wilkinson Catholic Education Trust (BWC...   Unknown
#
#                                                   Region  \
# 22329                                     United Kingdom
# 23378  United Kingdom,Isle of Man,Channel Islands,Bri...
# 34279                                         Any region
# 38897  United Kingdom,Belgium,Denmark,Estonia,Finland...
# 42004                                     United Kingdom
# ...                                                  ...
# 77058                                             London
# 77064                                                NaN
# 77141                                             London
# 77235                                                NaN
# 78744                                         Any region
#
#                                                Cpv Codes  ... Awarded Date  \
# 22329  34962230 35112100 38910000 38970000 39162200 4...  ...          NaT
# 23378  09310000 09331000 14213200 24111600 30162000 3...  ...          NaT
# 34279                                 65000000 72314000   ...          NaT
# 38897  22462000 30213100 32320000 39154000 48600000 5...  ...          NaT
# 42004      22200000 72310000 73000000 79000000 92400000   ...          NaT
# ...                                                  ...  ...          ...
# 77058                                          48000000   ...          NaT
# 77064                                          72000000   ...          NaT
# 77141                                          72000000   ...          NaT
# 77235                                          72000000   ...          NaT
# 78744  14000000 15000000 18000000 22000000 30000000 3...  ...          NaT
#
#       Awarded Value  \
# 22329           NaN
# 23378           NaN
# 34279           NaN
# 38897           NaN
# 42004           NaN
# ...             ...
# 77058           NaN
# 77064           NaN
# 77141           NaN
# 77235           NaN
# 78744           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 22329                                                NaN
# 23378                                                NaN
# 34279                                                NaN
# 38897                                                NaN
# 42004                                                NaN
# ...                                                  ...
# 77058                                                NaN
# 77064                                                NaN
# 77141                                                NaN
# 77235                                                NaN
# 78744                                                NaN
#
#       Contract start date Contract end date OJEU Procedure Type Closing Time  \
# 22329                 NaN               NaN         Restricted         23:59
# 23378                 NaN               NaN     RestrictedOJEU         00:00
# 34279                 NaN               NaN         Restricted         01:59
# 38897                 NaN               NaN     RestrictedOJEU         00:00
# 42004                 NaN               NaN     RestrictedOJEU         00:00
# ...                   ...               ...                 ...          ...
# 77058                 NaN               NaN           OpenOJEU         12:00
# 77064                 NaN               NaN        OpenNonOJEU         12:00
# 77141                 NaN               NaN           OpenOJEU         12:00
# 77235                 NaN               NaN           OpenOJEU         12:00
# 78744                 NaN               NaN         Restricted         00:00
#
#       Published Year Published Month  Year
# 22329           2020               1  2020
# 23378           2020               4  2020
# 34279           2021               4  2021
# 38897           2021               8  2021
# 42004           2021              11  2021
# ...              ...             ...   ...
# 77058           2024               8  2024
# 77064           2024               8  2024
# 77141           2024               7  2024
# 77235           2024               7  2024
# 78744           2022               5  2022
#
# [62 rows x 37 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame already loaded and processed

# Convert 'Published Date' to datetime if not already done
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Filter for contracts from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Convert 'Suitable for SME' and 'Suitable for VCO' to strings, then to boolean
df['Suitable for SME'] = df['Suitable for SME'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')
df['Suitable for VCO'] = df['Suitable for VCO'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')

# Add columns for the year
df['Published Year'] = df['Published Date'].dt.year

# Group by year and calculate the number of suitable contracts for SMEs and VCOs
yearly_sme_vco = df.groupby('Published Year').agg(
    Suitable_SME_Count=('Suitable for SME', 'sum'),
    Suitable_VCO_Count=('Suitable for VCO', 'sum')
).reset_index()

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_SME_Count'], marker='o', label='Suitable for SME')
plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_VCO_Count'], marker='x', label='Suitable for VCO')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Contracts')
plt.title('Number of Contracts Suitable for SMEs and VCOs (Yearly)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Print the results (as requested in the initial code)
total_contracts = df.shape[0]
suitable_for_sme = df['Suitable for SME'].sum()
suitable_for_vco = df['Suitable for VCO'].sum()
suitable_for_sme_percentage = (suitable_for_sme / total_contracts) * 100
suitable_for_vco_percentage = (suitable_for_vco / total_contracts) * 100

print(f'Percentage of contracts suitable for SMEs: {suitable_for_sme_percentage:.2f}%')
print(f'Percentage of contracts suitable for VCOs: {suitable_for_vco_percentage:.2f}%')
# Out:
# Percentage of contracts suitable for SMEs: 68.16%
# Percentage of contracts suitable for VCOs: 16.59%
