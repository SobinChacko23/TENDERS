# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load data from a CSV file (Replace 'data.csv' with your actual file name)
df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\NORTHERN IRELAND\NORTHERN IRELAND_CONTRACTS.csv")

# Display the first few rows to understand the data structure
print(df.head())
# Out:
#             Notice Identifier Notice Type  \
# 0                    MT174529    Contract
# 1   ESPO001-DN169032-84355864    Pipeline
# 2                    MT179131    Contract
# 3  NHSRDaSH-DN169835-32305934    Contract
# 4                    MT185069    Contract
#
#                               Organisation Name  Status  \
# 0                       Procurement for Housing  Closed
# 1                                          ESPO  Closed
# 2                             British Red Cross  Closed
# 3  Rotherham, Doncaster and South Humber NHS FT  Closed
# 4                     Five Councils Partnership  Closed
#
#               Published Date  \
# 0  2016-04-18T16:45:10+01:00
# 1  2016-06-27T08:54:24+01:00
# 2  2016-07-05T16:45:12+01:00
# 3  2016-07-04T11:44:08+01:00
# 4       2016-11-02T17:45:08Z
#
#                                                Title  \
# 0           Print & Multifunctional Device Solutions
# 1  7_16 Telephony, broadband and associated services
# 2  IT Hardware Solutions and Peripherals Framewor...
# 3  2144/T/TL/PD - Supply of paper to the Trusts P...
# 4  Provision of Website design and user experienc...
#
#                                          Description  Nationwide Postcode  \
# 0  Lot 1 - Print Management\r\nThe Print Manageme...         NaN      NaN
# 1  ESPO is seeking to establish a national framew...         NaN      NaN
# 2  Red Cross wishes to establish a Framework Agre...         NaN      NaN
# 3  2144/T/TL/PD - Supply of paper to the Trusts p...         NaN      NaN
# 4  We're seeking a professional designer to desig...         NaN      NaN
#
#                                               Region  ...  Value High  \
# 0  North East,Yorkshire and The Humber,North West...  ...  35000000.0
# 1                                         Any region  ...         NaN
# 2  Scotland,North East,Yorkshire and The Humber,N...  ...   2500000.0
# 3                                         Any region  ...         NaN
# 4                                         Any region  ...         NaN
#
#   Awarded Date Awarded Value  \
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN
#
#   Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Supplier's contact name Contract start date Contract end date  \
# 0                     NaN                 NaN               NaN
# 1                     NaN                 NaN               NaN
# 2                     NaN                 NaN               NaN
# 3                     NaN                 NaN               NaN
# 4                     NaN                 NaN               NaN
#
#   OJEU Procedure Type Accelerated Justification Closing Time
# 0         Restricted                        NaN          NaN
# 1                                           NaN          NaN
# 2               Open                        NaN          NaN
# 3               Open                        NaN          NaN
# 4               Open                        NaN          NaN
#
# [5 rows x 43 columns]
# C:\Users\sobin\AppData\Local\Temp\ipykernel_2008\690151826.py:4: DtypeWarning: Columns (8,27,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\NORTHERN IRELAND\NORTHERN IRELAND_CONTRACTS.csv")

# %%
# Convert 'Published Date' and 'Awarded Date' to datetime, ensuring UTC timezone and proper format parsing
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)
df['Awarded Date'] = pd.to_datetime(df['Awarded Date'], errors='coerce', utc=True)

# Filter for contracts where 'Status' is 'Awarded'
awarded_df = df[df['Status'] == 'Awarded']

# Fill missing 'Awarded Date' with 'Published Date' where 'Status' is 'Awarded'
awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# Filter for data from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Extract year and month for grouping
df['Published Year'] = df['Published Date'].dt.year
df['Published Month'] = df['Published Date'].dt.month
awarded_df['Awarded Year'] = awarded_df['Awarded Date'].dt.year
awarded_df['Awarded Month'] = awarded_df['Awarded Date'].dt.month

# Group and count the number of contracts published each month
published_counts = df.groupby(['Published Year', 'Published Month']).size().reset_index(name='Published Count')

# Group and count the number of contracts awarded each month
awarded_counts = awarded_df.groupby(['Awarded Year', 'Awarded Month']).size().reset_index(name='Awarded Count')

# Plotting the results
years = sorted(published_counts['Published Year'].unique())

for year in years:
    plt.figure(figsize=(10, 6))

    # Filter data for the current year
    published_data = published_counts[published_counts['Published Year'] == year]
    awarded_data = awarded_counts[awarded_counts['Awarded Year'] == year]
    
    # Plotting
    plt.plot(published_data['Published Month'], published_data['Published Count'], marker='o', label='Published')
    plt.plot(awarded_data['Awarded Month'], awarded_data['Awarded Count'], marker='x', label='Awarded')
    
    # Labels and title
    plt.xlabel('Month')
    plt.ylabel('Number of Contracts')
    plt.title(f'Contracts Published and Awarded in {year}')
    plt.legend()
    plt.grid(True)
    
    # Show the plot for the current year
    plt.show()
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_2008\51448626.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# %%
# Example strategy: Fill missing numeric values with 0 and categorical with 'Unknown'
df['Postcode'] = df['Postcode'].fillna('Unknown')
df['Value Low'] = df['Value Low'].fillna(0)
df['Value High'] = df['Value High'].fillna(0)

# %%
# Drop columns with excessive missing data if necessary (e.g., more than 50% missing)
df = df.dropna(thresh=len(df) * 0.5, axis=1)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Basic statistics
print(df.describe())

# Number of tenders by region
tenders_by_region = df['Region'].value_counts()
print("Tenders by Region:\n", tenders_by_region)

# Distribution of contract values
df['Value Low'] = pd.to_numeric(df['Value Low'], errors='coerce')
df['Value High'] = pd.to_numeric(df['Value High'], errors='coerce')

df[['Value Low', 'Value High']].hist(bins=50)
plt.show()
# Out:
#           Value Low    Value High  Awarded Value  Published Year  \
# count  1.655800e+04  1.655800e+04   1.345700e+04    16558.000000
# mean   1.531341e+08  2.031019e+07   2.635979e+07     2020.160406
# std    1.555273e+10  8.292522e+08   5.570580e+08        2.537631
# min    0.000000e+00  0.000000e+00   0.000000e+00     2015.000000
# 25%    2.541566e+04  0.000000e+00   4.000566e+04     2018.000000
# 50%    9.179750e+04  0.000000e+00   1.171000e+05     2021.000000
# 75%    4.779699e+05  1.390372e+04   5.160000e+05     2022.000000
# max    2.000000e+12  1.020000e+11   5.100000e+10     2024.000000
#
#        Published Month
# count     16558.000000
# mean          6.176833
# std           3.359985
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Tenders by Region:
#  Region
# Any region                                                                                                                                                                             11714
# United Kingdom                                                                                                                                                                          3712
# United Kingdom,Isle of Man,Channel Islands                                                                                                                                               302
# United Kingdom,Isle of Man,Channel Islands,British Oversea Territories,Europe,Rest of the World                                                                                          301
# North East,North West,Yorkshire and The Humber,East Midlands,West Midlands,East of England,London,South East,South West,Scotland,Wales,Northern Ireland,Isle of Man,Channel Islands      154
#                                                                                                                                                                                        ...
# North West,Wales,Northern Ireland                                                                                                                                                          1
# United Kingdom,Belgium,France                                                                                                                                                              1
# United Kingdom,Isle of Man,Channel Islands,Rest of the World                                                                                                                               1
# Northern Ireland,Ireland                                                                                                                                                                   1
# Any region,South East                                                                                                                                                                      1
# Name: count, Length: 72, dtype: int64

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import numpy as np

# Convert the 'Published Date' column to datetime, handling mixed time zones
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Drop rows where 'Published Date' could not be converted
df = df.dropna(subset=['Published Date'])

# Extract the year from the 'Published Date' column
df['Year'] = df['Published Date'].dt.year

# Filter data to include only contracts from 2015 onwards
df = df[df['Year'] >= 2015]

# Group data by year and count the number of tenders per year
annual_data = df.groupby('Year').size()

# Adjust the count for 2024 based on the number of months available (8/12)
if 2024 in annual_data.index:
    annual_data[2024] = annual_data[2024] * (12 / 8)

# Find optimal ARIMA order
model = auto_arima(annual_data, seasonal=False)
model_fit = model.fit(annual_data)

# Predict the next 5 years
forecast, conf_int = model_fit.predict(n_periods=5, return_conf_int=True)

# Create forecast years
forecast_years = np.arange(annual_data.index[-1] + 1, annual_data.index[-1] + 6)

# Plot the historical data and the forecast
plt.figure(figsize=(12, 8))
plt.plot(annual_data.index, annual_data, label='Historical Data', color='steelblue', marker='o', linestyle='-')
plt.plot(forecast_years, forecast, label='Forecast', color='darkorange', linestyle='--', marker='x')

# Add confidence intervals
plt.fill_between(forecast_years, conf_int[:, 0], conf_int[:, 1], color='darkorange', alpha=0.3)

# Annotations and labels
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Tenders', fontsize=14)
plt.title('Forecast of Number of Tenders from 2015 for the Next 5 Years', fontsize=16)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(np.arange(min(annual_data.index), max(forecast_years) + 1, 1), rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd

# Convert 'Start Date' and 'End Date' to datetime, handling any errors
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', utc=True)
df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)

# Ensure 'Status' column is of type string
df['Status'] = df['Status'].astype(str)

# Count frameworks by type and region
framework_by_region = df.groupby(['Region', 'OJEU Contract Type']).size().unstack(fill_value=0)
print("Frameworks by Region and Type:\n", framework_by_region)

# For live and upcoming frameworks, filter based on date and status
current_year = pd.Timestamp.now().year

# Filter for live frameworks
live_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) & 
    (df['End Date'].notna()) &
    (df['Start Date'].dt.year <= current_year) &
    (df['End Date'].dt.year >= current_year)
]

# Filter for upcoming frameworks
upcoming_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) &
    (df['Start Date'].dt.year > current_year)
]

print("Live Frameworks:\n", live_frameworks)
print("Upcoming Frameworks:\n", upcoming_frameworks)
# Out:
# Frameworks by Region and Type:
#  OJEU Contract Type                              NotApplicable  NotSpecified  \
# Region
# Any region                                                249           176
# Any region,East Midlands,East of England                    0             0
# Any region,East Midlands,West Midlands                      0             0
# Any region,East of England                                  0             0
# Any region,London                                           0             0
# ...                                                       ...           ...
# United Kingdom,Mexico                                       0             0
# United Kingdom,Rest of the World                            0             0
# United Kingdom,United States                                0             0
# West Midlands,London,Scotland,Northern Ireland              0             0
# Yorkshire and The Humber,United Kingdom                     0             0
#
# OJEU Contract Type                              Products  Services  Works
# Region
# Any region                                          2804      7948    121
# Any region,East Midlands,East of England               0         1      0
# Any region,East Midlands,West Midlands                 0         3      0
# Any region,East of England                             1         2      0
# Any region,London                                      3        31      0
# ...                                                  ...       ...    ...
# United Kingdom,Mexico                                  0         4      0
# United Kingdom,Rest of the World                       1         0      0
# United Kingdom,United States                           1         0      0
# West Midlands,London,Scotland,Northern Ireland         0         2      0
# Yorkshire and The Humber,United Kingdom                0         1      0
#
# [69 rows x 5 columns]
# Live Frameworks:
#                     Notice Identifier     Notice Type  \
# 1819                          RM6235        Contract
# 6356                          RM6235        Contract
# 7757                  FCTRFQ03/24-01        Pipeline
# 8127           20240729203800-119413        Contract
# 8172                    BIP872421405        Contract
# 8200                   C24-0484-1922        Contract
# 8205                    BIP879601180        Contract
# 8218      STHOX001-DN735017-73889574        Contract
# 8222           tender_455196/1386728        Contract
# 8235           tender_440638/1374739        Contract
# 8305                         376E_24        Contract
# 8354           tender_435626/1393676        Contract
# 8362                        2024-717        Contract
# 8382     CHEAST001-DN736854-10873064        Contract
# 8387           tender_446106/1392530        Contract
# 8393      GOSPT001-DN736351-02296027        Contract
# 8396       AHSN001-DN670401-77820277  PreProcurement
# 8400                      YFFIE00124        Contract
# 8411            20240731180746-72814        Contract
# 8415      GOSPT001-DN735694-96897808        Contract
# 8424       MANC001-DN734747-03973553        Contract
# 8444       AHSN001-DN670401-69684874  PreProcurement
# 8445       AHSN001-DN670401-43079167  PreProcurement
# 8446       GREENCH-DN733527-02777469        Contract
# 8454       GREENCH-DN733245-82283485        Contract
# 8568                  FCTRFQ03/24-01        Pipeline
# 15659  NPSBARNS001-DN536468-59820066        Pipeline
#
#                                      Organisation Name Status  \
# 1819                          Crown Commercial Service   Open
# 6356                          Crown Commercial Service   Open
# 7757                                              Espo   Open
# 8127                      Hyde Housing Association Ltd   Open
# 8172                                   British Library   Open
# 8200                                   JNCC SUPPORT CO   Open
# 8205                  The Corporation of Trinity House   Open
# 8218                South Oxfordshire District Council   Open
# 8222        The British Broadcasting Corporation (BBC)   Open
# 8235        The British Broadcasting Corporation (BBC)   Open
# 8305                                              Espo   Open
# 8354                Department for International Trade   Open
# 8362   DEPARTMENT FOR ENVIRONMENT FOOD & RURAL AFFAIRS   Open
# 8382                     Cheshire East Borough Council   Open
# 8387        The British Broadcasting Corporation (BBC)   Open
# 8393                           Gosport Borough Council   Open
# 8396    Health Innovation North East and North Cumbria   Open
# 8400                  YOUTH FUTURES FOUNDATION LIMITED   Open
# 8411            United Kingdom Atomic Energy Authority   Open
# 8415                           Gosport Borough Council   Open
# 8424                           Manchester City Council   Open
# 8444    Health Innovation North East and North Cumbria   Open
# 8445    Health Innovation North East and North Cumbria   Open
# 8446                         Eastlight Community Homes   Open
# 8454                         Eastlight Community Homes   Open
# 8568                                              Espo   Open
# 15659            Barnsley Metropolitan Borough Council   Open
# 8362   FARM ENVIRONMENT DATA EXPERTISE SUPPORT\r\nAHD...  Unknown
# 8382   CONTRACT FOR THE PROVISION OF  ONLINE PLANNING...  Unknown
# 8387   This requirement is focused on the delivery of...  Unknown
# 8393   Gosport Borough Council are looking for Contra...  Unknown
# 8396   Repurposing devices through either recycling o...  Unknown
# 8400   As a What Works Centre that wants to drive cha...  Unknown
# 8411   The UKAEA has a requirement for a Computerised...  Unknown
# 8415   Gosport Borough Council (GBC) is inviting quot...  Unknown
# 8424   Manchester City Council seeks to a Market Admi...  Unknown
# 8444   The purpose of this PIN is to inform market op...  Unknown
# 8445   The purpose of this PIN is to inform market op...  Unknown
# 8446   Eastlight currently uses Keystone for asset ma...  Unknown
# 8454   Eastlight currently uses Keystone for asset ma...  Unknown
# 8568   This is a Prior Information Notice where the t...  Unknown
# 15659  To consolidate the contracts in the management...  Unknown
#
#                Region                                          Cpv Codes  ...  \
# 1819   United Kingdom  32210000 32412100 32510000 32530000 38115100 3...  ...
# 6356   United Kingdom  32210000 32412100 32510000 32530000 38115100 3...  ...
# 7757   United Kingdom                                 48000000 72000000   ...
# 8127       Any region  66171000 71241000 71242000 71244000 72224000 7...  ...
# 8172       Any region                                          72212321   ...
# 8200   United Kingdom      72224000 73000000 79000000 92000000 98000000   ...
# 8205       Any region                                 79410000 72224000   ...
# 8218   United Kingdom                        72221000 79000000 80500000   ...
# 8222       Any region                                          72268000   ...
# 8235       Any region                                          72322000   ...
# 8305   United Kingdom      22110000 22200000 48160000 79980000 92511000   ...
# 8354       Any region                                          72300000   ...
# 8362   United Kingdom                        72300000 77100000 90714100   ...
# 8382   United Kingdom                                          48000000   ...
# 8387       Any region                                          48000000   ...
# 8393   United Kingdom                                          72000000   ...
# 8396   United Kingdom                                 30000000 72000000   ...
# 8400   United Kingdom                                 48000000 72000000   ...
# 8411       Any region      48000000 48100000 48420000 48421000 48422000   ...
# 8415   United Kingdom                                          48000000   ...
# 8424   United Kingdom                                 48000000 72260000   ...
# 8444   United Kingdom                                 30000000 72000000   ...
# 8445   United Kingdom                                 30000000 72000000   ...
# 8446   United Kingdom                                          72000000   ...
# 8454   United Kingdom                                          72000000   ...
# 8568   United Kingdom                                 48000000 72000000   ...
# 15659  United Kingdom                                 48000000 72000000   ...
#
#         Value High Awarded Value  \
# 1819           0.0           NaN
# 6356           0.0           NaN
# 7757           0.0           NaN
# 8127   360000000.0           NaN
# 8172           0.0           NaN
# 8200           0.0           NaN
# 8205      500000.0           NaN
# 8218       50000.0           NaN
# 8222     1000000.0           NaN
# 8235           0.0           NaN
# 8305           0.0           NaN
# 8354      200000.0           NaN
# 8362           0.0           NaN
# 8382      100000.0           NaN
# 8387           0.0           NaN
# 8393      364100.0           NaN
# 8396     3000000.0           NaN
# 8400      200000.0           NaN
# 8411     4080000.0           NaN
# 8415       40000.0           NaN
# 8424      450000.0           NaN
# 8444     3000000.0           NaN
# 8445     3000000.0           NaN
# 8446      351000.0           NaN
# 8454      351000.0           NaN
# 8568           0.0           NaN
# 15659      48622.0           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 1819                                                 NaN
# 6356                                                 NaN
# 7757                                                 NaN
# 8127                                                 NaN
# 8172                                                 NaN
# 8200                                                 NaN
# 8205                                                 NaN
# 8218                                                 NaN
# 8222                                                 NaN
# 8235                                                 NaN
# 8305                                                 NaN
# 8354                                                 NaN
# 8362                                                 NaN
# 8382                                                 NaN
# 8387                                                 NaN
# 8393                                                 NaN
# 8396                                                 NaN
# 8400                                                 NaN
# 8411                                                 NaN
# 8415                                                 NaN
# 8424                                                 NaN
# 8444                                                 NaN
# 8445                                                 NaN
# 8446                                                 NaN
# 8454                                                 NaN
# 8568                                                 NaN
# 15659                                                NaN
#
#       Contract start date Contract end date OJEU Procedure Type Closing Time  \
# 1819                  NaN               NaN     RestrictedOJEU         11:59
# 6356                  NaN               NaN     RestrictedOJEU         11:59
# 7757                  NaN               NaN           OpenOJEU           NaN
# 8127                  NaN               NaN               Open         12:00
# 8172                  NaN               NaN               Open         00:00
# 8200                  NaN               NaN        OpenNonOJEU         16:00
# 8205                  NaN               NaN               Open         12:00
# 8218                  NaN               NaN        OpenNonOJEU         17:00
# 8222                  NaN               NaN           OpenOJEU         12:00
# 8235                  NaN               NaN           OpenOJEU         10:00
# 8305                  NaN               NaN           OpenOJEU         12:00
# 8354                  NaN               NaN           OpenOJEU         17:00
# 8362                  NaN               NaN        OpenNonOJEU         12:00
# 8382                  NaN               NaN        OpenNonOJEU         12:00
# 8387                  NaN               NaN           OpenOJEU         14:00
# 8393                  NaN               NaN           OpenOJEU         12:00
# 8396                  NaN               NaN                              NaN
# 8400                  NaN               NaN        OpenNonOJEU         18:00
# 8411                  NaN               NaN         Restricted         12:00
# 8415                  NaN               NaN        OpenNonOJEU         12:00
# 8424                  NaN               NaN           OpenOJEU         11:00
# 8444                  NaN               NaN                              NaN
# 8445                  NaN               NaN                              NaN
# 8446                  NaN               NaN     RestrictedOJEU         12:00
# 8454                  NaN               NaN     RestrictedOJEU         12:00
# 8568                  NaN               NaN           OpenOJEU           NaN
# 15659                 NaN               NaN                              NaN
#
#       Published Year Published Month  Year
# 1819            2021               9  2021
# 6356            2021               9  2021
# 7757            2024               4  2024
# 8127            2024               7  2024
# 8172            2024               7  2024
# 8200            2024               7  2024
# 8205            2024               8  2024
# 8218            2024               7  2024
# 8222            2024               7  2024
# 8235            2024               7  2024
# 8305            2024               7  2024
# 8354            2024               8  2024
# 8362            2024               7  2024
# 8382            2024               8  2024
# 8387            2024               8  2024
# 8393            2024               8  2024
# 8396            2024               8  2024
# 8400            2024               8  2024
# 8411            2024               7  2024
# 8415            2024               7  2024
# 8424            2024               7  2024
# 8444            2024               7  2024
# 8445            2024               7  2024
# 8446            2024               7  2024
# 8454            2024               7  2024
# 8568            2024               4  2024
# 15659           2021               4  2021
#
# [27 rows x 35 columns]
# Upcoming Frameworks:
#                                        Notice Identifier Notice Type  \
# 987                                              RM6124    Contract
# 2068                                             RM6126    Contract
# 2201                                            RM6242.    Contract
# 3065   Automation Marketplace Dynamic Purchasing System    Contract
# 3932                                      CIMPLE-237688    Contract
# 4118                                            RM6242.    Contract
# 4165                         EPAS17 (EPL - 2015 - 0032)    Contract
# 4406                                             RM6322    Contract
# 4412                                             RM6264    Contract
# 4848                                        RM3764.iii.    Contract
# 4927                                            RM3825.    Contract
# 4957                                      CIMPLE-237688    Contract
# 5355                                             RM6264    Contract
# 5767                                             RM6126    Contract
# 5897                                      CIMPLE-339612    Contract
# 5900                                             RM6190    Pipeline
# 6339                                             RM6343    Pipeline
# 6358                                             RM6322    Contract
# 6366                                             RM6354    Pipeline
# 6368                                           RM6200..    Contract
# 6532                                             RM6353    Pipeline
# 6745                                           RM6148..    Contract
# 6767                                             RM6295    Pipeline
# 6943                                             RM6095    Contract
# 7107                                      CIMPLE-339612    Contract
# 7212                                             RM6190    Pipeline
# 7232                                             RM6343    Pipeline
# 7255                                             RM6356    Pipeline
# 7657                                        RM3764.iii.    Contract
# 7718                           YPO001-DN433526-71875119    Contract
# 7761                                             RM6213    Contract
# 7778                                            RM6361.    Pipeline
# 7797                                             RM6366    Pipeline
# 7951                                             RM6365    Pipeline
# 8111                                             RM6346    Pipeline
# 8113                                             158_25    Contract
# 8116                                            RM6302.    Pipeline
# 8120                                             RM6364    Pipeline
# 8121                                           RM6200..    Contract
# 8125                                             RM6124    Contract
# 8129                                             RM6356    Pipeline
# 8268                              tender_442882/1365677    Pipeline
# 8381                                             664_25    Contract
# 8429                                             RM6285    Contract
# 8447                           ECC001-DN706093-33619574    Contract
# 8461   Automation Marketplace Dynamic Purchasing System    Contract
# 8462                                            RM3825.    Contract
# 8570                              tender_399335/1303281    Contract
# 12679                        EPAS17 (EPL - 2015 - 0032)    Contract
# 13558                          YPO001-DN433526-71875119    Contract
# 13630                                            RM6213    Contract
# 13631                                            RM6095    Contract
# 14693                              20201016093029-30310    Contract
# 15204                          YPO001-DN517178-18851510    Contract
#
#                                       Organisation Name Status  \
# 987                            Crown Commercial Service   Open
# 2068                           Crown Commercial Service   Open
# 2201                           Crown Commercial Service   Open
# 3065                           Crown Commercial Service   Open
# 3932          Bishop Wilkinson Catholic Education Trust   Open
# 4118                           Crown Commercial Service   Open
# 4165                        EASTERN PROCUREMENT LIMITED   Open
# 4406                           Crown Commercial Service   Open
# 4412                           Crown Commercial Service   Open
# 4848                           Crown Commercial Service   Open
# 4927                           Crown Commercial Service   Open
# 4957          Bishop Wilkinson Catholic Education Trust   Open
# 5355                           Crown Commercial Service   Open
# 5767                           Crown Commercial Service   Open
# 5897                              HEART ACADEMIES TRUST   Open
# 5900                           Crown Commercial Service   Open
# 6339                           Crown Commercial Service   Open
# 6358                           Crown Commercial Service   Open
# 6366                           Crown Commercial Service   Open
# 6368                           Crown Commercial Service   Open
# 6532                           Crown Commercial Service   Open
# 6745                           Crown Commercial Service   Open
# 6767                           Crown Commercial Service   Open
# 6943                           Crown Commercial Service   Open
# 7107                              HEART ACADEMIES TRUST   Open
# 7212                           Crown Commercial Service   Open
# 7232                           Crown Commercial Service   Open
# 7255                           Crown Commercial Service   Open
# 7657                           Crown Commercial Service   Open
# 7718                                                YPO   Open
# 7761                           Crown Commercial Service   Open
# 14693 2020-10-16 08:30:32+00:00
# 15204 2021-04-08 08:23:59+00:00
#
#                                                    Title  \
# 987                           Communications Marketplace
# 2068                           Research and Insights DPS
# 2201              Construction Professional Services DPS
# 3065                                              RM6173
# 3932   A DPS for sustainable and ethically sourced go...
# 4118              Construction Professional Services DPS
# 4165        DPS - Dynamic Supplier List: Asset Solutions
# 4406     Fund Administration & Disbursement Services DPS
# 4412      Facilities Management & Workplace Services DPS
# 4848                           Cyber Security Services 3
# 4927   Health and Social Care Network (HSCN) Access S...
# 4957   A DPS for sustainable and ethically sourced go...
# 5355      Facilities Management & Workplace Services DPS
# 5767                           Research and Insights DPS
# 5897   Dynamic Purchasing System (DPS) for the provis...
# 5900                               Technology Services 4
# 6339                        Estate Management Services 2
# 6358     Fund Administration & Disbursement Services DPS
# 6366   Courier, Distribution, Storage and Specialist ...
# 6368                         Artificial Intelligence DPS
# 6532                           Tyres, Glass & Telematics
# 6745   Quality Assurance and Testing for IT Systems 2...
# 6767                                 Outsourced Services
# 6943              Gigabit Capable Connectivity Extension
# 7107   Dynamic Purchasing System (DPS) for the provis...
# 7212                               Technology Services 4
# 7232                        Estate Management Services 2
# 7255                Construction Professional Services 2
# 7657                           Cyber Security Services 3
# 7718   YPO - 000999 Training for The Emergency Servic...
# 7761     Vehicle Charging Infrastructure Solutions (DPS)
# 7778   Multifunctional Devices (MFDs), Print, Digital...
# 7797                          Debt Resolution Services 2
# 7951   Pre-Market Engagement for RM1043.8 Digital Out...
# 8111   Records Information Management, Digital Soluti...
# 8113   158_25 Paints, Chalks, Crayons and other Art-R...
# 8116                                   Language Services
# 8120                           Media & Creative Services
# 8121                         Artificial Intelligence DPS
# 8125                          Communications Marketplace
# 8129                Construction Professional Services 2
# 8268                 Application Development and Support
# 8381                         664_25 Consultancy Services
# 8429                             Back Office Software 2.
# 8447                     CO0437 - Data Management System
# 8461                                              RM6173
# 8462   Health and Social Care Network (HSCN) Access S...
# 8570   VOLUNTARY TRANSPARENCY NOTICE: MODE 5 IDENTIFI...
# 12679       DPS - Dynamic Supplier List: Asset Solutions
# 13558  YPO - 000999 Training for The Emergency Servic...
# 13630    Vehicle Charging Infrastructure Solutions (DPS)
# 13631             Gigabit Capable Connectivity Extension
# 14693  National Agreement for the Provision of Digita...
# 15204      YPO - 001056 Metering and Meter Data Services
#
#                                              Description Postcode  \
# 987    The Communications Marketplace DPS Agreement w...  Unknown
# 2068   Crown Commercial Service (CCS) as the authorit...  Unknown
# 2201   The RM6242 DPS will be organised into distinct...  Unknown
# 3065   Automation services including the design, buil...  Unknown
# 3932   Bishop Wilkinson Catholic Education Trust (BWC...  Unknown
# 4118   The RM6242 DPS will be organised into distinct...  Unknown
# 4165   Dear Contractor Thank you for your interest in...  Unknown
# 4406   Crown Commercial Service (CCS), as the Authori...  Unknown
# 4412   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 4848   Crown Commercial Service (CCS) has set up a dy...  Unknown
# 4927   Crown Commercial Service (the Authority) has p...  Unknown
# 4957   Bishop Wilkinson Catholic Education Trust (BWC...  Unknown
# 5355   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 5767   Crown Commercial Service (CCS) as the authorit...  Unknown
# 5897   HEART Academies Trust (HEART) are seeking to e...  Unknown
# 5900   Crown Commercial Service, as the Authority, in...  Unknown
# 6339   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 6358   Crown Commercial Service (CCS), as the Authori...  Unknown
# 6366   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 6368   Crown Commercial Service has set up a Dynamic ...  Unknown
# 6532   Crown Commercial Service, as the Authority,  i...  Unknown
# 6745   Crown Commercial Service (CCS) is setting up a...  Unknown
# 6767   Crown Commercial Service, as the Authority, in...  Unknown
# 6943   Crown Commercial Service (CCS) set up a Dynami...  Unknown
# 7107   HEART Academies Trust (HEART) are seeking to e...  Unknown
# 7212   Crown Commercial Service, as the Authority, in...  Unknown
# 7232   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7255   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7657   Crown Commercial Service (CCS) has set up a dy...  Unknown
# 7718   YPO are looking for Suppliers to be appointed ...  Unknown
# 7761   CCS has a dynamic purchasing system for Vehicl...  Unknown
# 7778   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7797   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7951   Crown Commercial Service intends to hold marke...  Unknown
# 8111   Crown Commercial Service (CCS) acting as the A...  Unknown
# 8113   The supply of paints, chalks crayons and other...  Unknown
# 8116   Crown Commercial Service, as the Authority, in...  Unknown
# 8120   The Marketing & Communications Category (Marco...  Unknown
# 8121   Crown Commercial Service has set up a Dynamic ...  Unknown
# 8125   The Communications Marketplace DPS Agreement w...  Unknown
# 8129   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 8268   The Specialist EOD, Exploitation and Counter M...  Unknown
# 8381   ESPO on behalf of ESPO and YPO are seeking to ...  Unknown
# 8429   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 8447   Essex County Council (ECC) currently uses a Da...  Unknown
# 8461   Automation services including the design, buil...  Unknown
# 8462   Crown Commercial Service (the Authority) has p...  Unknown
# 8570   VOLUNTARY TRANSPARENCY NOTICE (VTN) TO PLACE A...  Unknown
# 12679  Dear Contractor Thank you for your interest in...  Unknown
# 13558  YPO are looking for Suppliers to be appointed ...  Unknown
# 13630  CCS has a dynamic purchasing system for Vehicl...  Unknown
# 13631  Crown Commercial Service (CCS) set up a Dynami...  Unknown
# 14693  The Forensic Capability Network (FCN - the Aut...  Unknown
# 15204  YPO are looking for Suppliers to be appointed ...  Unknown
#
#                                                   Region  \
# 987    United Kingdom,Belgium,Denmark,Estonia,Finland...
# 2068                                      United Kingdom
# 2201                                      United Kingdom
# 3065                                      United Kingdom
# 3932                                          Any region
# 4118                                      United Kingdom
# 4165   United Kingdom,Isle of Man,Channel Islands,Bri...
# 4406                                      United Kingdom
# 4412                                      United Kingdom
# 4848                                      United Kingdom
# 4927                                      United Kingdom
# 4957                                          Any region
# 5355                                      United Kingdom
# 5767                                      United Kingdom
# 5897                                          Any region
# 5900                                      United Kingdom
# 6339                                      United Kingdom
# 6358                                      United Kingdom
# 6366                                      United Kingdom
# 6368                                      United Kingdom
# 6532                                      United Kingdom
# 6745                                      United Kingdom
# 6767                                      United Kingdom
# 6943   United Kingdom,Isle of Man,Channel Islands,Bri...
# 7107                                          Any region
# 7212                                      United Kingdom
# 7232                                      United Kingdom
# 7255                                      United Kingdom
# 7657                                      United Kingdom
# 7718                                      United Kingdom
# 7761   United Kingdom,Isle of Man,Channel Islands,Bri...
# 7778                                      United Kingdom
# 7797                                      United Kingdom
# 7951                                      United Kingdom
# 8381   66170000 66600000 70333000 71241000 71311200 7...  ...          0.0
# 8429                                  48000000 72000000   ...          0.0
# 8447                                  72000000 72220000   ...          0.0
# 8461                                           72000000   ...          0.0
# 8462   32000000 48510000 48760000 50334400 51300000 6...  ...          0.0
# 8570                                  32000000 50000000   ...   16000000.0
# 12679  03419000 14630000 24963000 31300000 31680000 3...  ...          0.0
# 13558  34962230 35112100 38910000 38970000 39162200 4...  ...  200000000.0
# 13630  09310000 09331000 14213200 24111600 30162000 3...  ...          0.0
# 13631                                          32000000   ...          0.0
# 14693  60000000 64120000 71600000 71610000 71620000 7...  ...   60000000.0
# 15204                                 65000000 72314000   ...   10000000.0
#
#       Awarded Value  \
# 987             NaN
# 2068            NaN
# 2201            NaN
# 3065            NaN
# 3932            NaN
# 4118            NaN
# 4165            NaN
# 4406            NaN
# 4412            NaN
# 4848            NaN
# 4927            NaN
# 4957            NaN
# 5355            NaN
# 5767            NaN
# 5897            NaN
# 5900            NaN
# 6339            NaN
# 6358            NaN
# 6366            NaN
# 6368            NaN
# 6532            NaN
# 6745            NaN
# 6767            NaN
# 6943            NaN
# 7107            NaN
# 7212            NaN
# 7232            NaN
# 7255            NaN
# 7657            NaN
# 7718            NaN
# 7761            NaN
# 7778            NaN
# 7797            NaN
# 7951            NaN
# 8111            NaN
# 8113            NaN
# 8116            NaN
# 8120            NaN
# 8121            NaN
# 8125            NaN
# 8129            NaN
# 8268            NaN
# 8381            NaN
# 8429            NaN
# 8447            NaN
# 8461            NaN
# 8462            NaN
# 8570            NaN
# 12679           NaN
# 13558           NaN
# 13630           NaN
# 13631           NaN
# 14693           NaN
# 15204           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 987                                                  NaN
# 2068                                                 NaN
# 2201                                                 NaN
# 3065                                                 NaN
# 3932                                                 NaN
# 4118                                                 NaN
# 4165                                                 NaN
# 4406                                                 NaN
# 4412                                                 NaN
# 4848                                                 NaN
# 4927                                                 NaN
# 4957                                                 NaN
# 5355                                                 NaN
# 5767                                                 NaN
# 5897                                                 NaN
# 5900                                                 NaN
# 6339                                                 NaN
# 6358                                                 NaN
# 6366                                                 NaN
# 6368                                                 NaN
# 6532                                                 NaN
# 6745                                                 NaN
# 6767                                                 NaN
# 6943                                                 NaN
# 7107                                                 NaN
# 7212                                                 NaN
# 7232                                                 NaN
# 7255                                                 NaN
# 7657                                                 NaN
# 7718                                                 NaN
# 7761                                                 NaN
# 7778                                                 NaN
# 7797                                                 NaN
# 7951                                                 NaN
# 8111                                                 NaN
# 8113                                                 NaN
# 8116                                                 NaN
# 8120                                                 NaN
# 8121                                                 NaN
# 8125                                                 NaN
# 8129                                                 NaN
# 8268                                                 NaN
# 8381                                                 NaN
# 8429                                                 NaN
# 8447                                                 NaN
# 8461                                                 NaN
# 8462                                                 NaN
# 8570                                                 NaN
# 12679                                                NaN
# 13558                                                NaN
# 13630                                                NaN
# 13631                                                NaN
# 14693                                                NaN
# 15204                                                NaN
#
#       Contract start date Contract end date         OJEU Procedure Type  \
# 987                   NaN               NaN             RestrictedOJEU
# 2068                  NaN               NaN             RestrictedOJEU
# 6532           NaN           2023               9  2023
# 6745         00:00           2023              11  2023
# 6767           NaN           2023               9  2023
# 6943         23:59           2019              10  2019
# 7107         00:00           2023               8  2023
# 7212           NaN           2023               8  2023
# 7232           NaN           2023               9  2023
# 7255           NaN           2024               5  2024
# 7657         00:00           2022              12  2022
# 7718         23:59           2020               1  2020
# 7761         00:00           2020               4  2020
# 7778           NaN           2024               5  2024
# 7797           NaN           2024               5  2024
# 7951           NaN           2024               3  2024
# 8111           NaN           2024               7  2024
# 8113         12:00           2024               7  2024
# 8116           NaN           2024               7  2024
# 8120           NaN           2024               6  2024
# 8121         23:59           2023              11  2023
# 8125         00:00           2021               8  2021
# 8129           NaN           2024               5  2024
# 8268           NaN           2024               6  2024
# 8381         12:00           2024               8  2024
# 8429         15:00           2024               7  2024
# 8447         12:00           2024               7  2024
# 8461         00:00           2022               4  2022
# 8462         00:00           2023               1  2023
# 8570         12:00           2024               6  2024
# 12679        12:00           2019               4  2019
# 13558        23:59           2020               1  2020
# 13630        00:00           2020               4  2020
# 13631        23:59           2019              10  2019
# 14693        12:00           2020              10  2020
# 15204        01:59           2021               4  2021
#
# [54 rows x 35 columns]
# C:\Users\sobin\AppData\Local\Temp\ipykernel_2008\1426416616.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', utc=True)
# C:\Users\sobin\AppData\Local\Temp\ipykernel_2008\1426416616.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame already loaded and processed

# Convert 'Published Date' to datetime if not already done
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Filter for contracts from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Convert 'Suitable for SME' and 'Suitable for VCO' to strings, then to boolean
df['Suitable for SME'] = df['Suitable for SME'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')
df['Suitable for VCO'] = df['Suitable for VCO'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')

# Add columns for the year
df['Published Year'] = df['Published Date'].dt.year

# Group by year and calculate the number of suitable contracts for SMEs and VCOs
yearly_sme_vco = df.groupby('Published Year').agg(
    Suitable_SME_Count=('Suitable for SME', 'sum'),
    Suitable_VCO_Count=('Suitable for VCO', 'sum')
).reset_index()

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_SME_Count'], marker='o', label='Suitable for SME')
plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_VCO_Count'], marker='x', label='Suitable for VCO')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Contracts')
plt.title('Number of Contracts Suitable for SMEs and VCOs (Yearly)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Print the results (as requested in the initial code)
total_contracts = df.shape[0]
suitable_for_sme = df['Suitable for SME'].sum()
suitable_for_vco = df['Suitable for VCO'].sum()
suitable_for_sme_percentage = (suitable_for_sme / total_contracts) * 100
suitable_for_vco_percentage = (suitable_for_vco / total_contracts) * 100

print(f'Percentage of contracts suitable for SMEs: {suitable_for_sme_percentage:.2f}%')
print(f'Percentage of contracts suitable for VCOs: {suitable_for_vco_percentage:.2f}%')
# Out:
# Percentage of contracts suitable for SMEs: 69.03%
# Percentage of contracts suitable for VCOs: 19.83%
