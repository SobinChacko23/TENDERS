# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load data from a CSV file (Replace 'data.csv' with your actual file name)
df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\SCOTLAND\SCOTLAND_CONTRACTS.csv")

# Display the first few rows to understand the data structure
print(df.head())
# Out:
#             Notice Identifier Notice Type  \
# 0                    RSSB2435    Contract
# 1                   DWP101976    Contract
# 2   ESPO001-DN169032-84355864    Pipeline
# 3                    MT179131    Contract
# 4  NHSRDaSH-DN169835-32305934    Contract
#
#                               Organisation Name  Status  \
# 0       RAIL SAFETY AND STANDARDS BOARD LIMITED  Closed
# 1              DEPARTMENT FOR WORK AND PENSIONS  Closed
# 2                                          ESPO  Closed
# 3                             British Red Cross  Closed
# 4  Rotherham, Doncaster and South Humber NHS FT  Closed
#
#               Published Date  \
# 0       2017-02-03T16:40:31Z
# 1       2017-01-20T11:41:07Z
# 2  2016-06-27T08:54:24+01:00
# 3  2016-07-05T16:45:12+01:00
# 4  2016-07-04T11:44:08+01:00
#
#                                                Title  \
# 0            Audio Visual Equipment and Staging Hire
# 1           DWP Document and Data Management Service
# 2  7_16 Telephony, broadband and associated services
# 3  IT Hardware Solutions and Peripherals Framewor...
# 4  2144/T/TL/PD - Supply of paper to the Trusts P...
#
#                                          Description  Nationwide Postcode  \
# 0  RSSB requires a flexible, zero value commitmen...         NaN      NaN
# 1  DWP is looking for the provision of a future s...         NaN      NaN
# 2  ESPO is seeking to establish a national framew...         NaN      NaN
# 3  Red Cross wishes to establish a Framework Agre...         NaN      NaN
# 4  2144/T/TL/PD - Supply of paper to the Trusts p...         NaN      NaN
#
#                                               Region  ... Value High  \
# 0                                         Any region  ...    80000.0
# 1                                         Any region  ...        NaN
# 2                                         Any region  ...        NaN
# 3  Scotland,North East,Yorkshire and The Humber,N...  ...  2500000.0
# 4                                         Any region  ...        NaN
#
#   Awarded Date Awarded Value  \
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN
#
#   Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Supplier's contact name Contract start date Contract end date  \
# 0                     NaN                 NaN               NaN
# 1                     NaN                 NaN               NaN
# 2                     NaN                 NaN               NaN
# 3                     NaN                 NaN               NaN
# 4                     NaN                 NaN               NaN
#
#   OJEU Procedure Type Accelerated Justification Closing Time
# 0              Other                        NaN          NaN
# 1               Open                        NaN          NaN
# 2                                           NaN          NaN
# 3               Open                        NaN          NaN
# 4               Open                        NaN          NaN
#
# [5 rows x 43 columns]
# C:\Users\sobin\AppData\Local\Temp\ipykernel_14744\460598758.py:4: DtypeWarning: Columns (8,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\SOBIN_CHACKO\TENDERS\SCOTLAND\SCOTLAND_CONTRACTS.csv")

# %%
# Convert 'Published Date' and 'Awarded Date' to datetime, ensuring UTC timezone and proper format parsing
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)
df['Awarded Date'] = pd.to_datetime(df['Awarded Date'], errors='coerce', utc=True)

# Filter for contracts where 'Status' is 'Awarded'
awarded_df = df[df['Status'] == 'Awarded']

# Fill missing 'Awarded Date' with 'Published Date' where 'Status' is 'Awarded'
awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# Filter for data from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Extract year and month for grouping
df['Published Year'] = df['Published Date'].dt.year
df['Published Month'] = df['Published Date'].dt.month
awarded_df['Awarded Year'] = awarded_df['Awarded Date'].dt.year
awarded_df['Awarded Month'] = awarded_df['Awarded Date'].dt.month

# Group and count the number of contracts published each month
published_counts = df.groupby(['Published Year', 'Published Month']).size().reset_index(name='Published Count')

# Group and count the number of contracts awarded each month
awarded_counts = awarded_df.groupby(['Awarded Year', 'Awarded Month']).size().reset_index(name='Awarded Count')

# Plotting the results
years = sorted(published_counts['Published Year'].unique())

for year in years:
    plt.figure(figsize=(10, 6))

    # Filter data for the current year
    published_data = published_counts[published_counts['Published Year'] == year]
    awarded_data = awarded_counts[awarded_counts['Awarded Year'] == year]
    
    # Plotting
    plt.plot(published_data['Published Month'], published_data['Published Count'], marker='o', label='Published')
    plt.plot(awarded_data['Awarded Month'], awarded_data['Awarded Count'], marker='x', label='Awarded')
    
    # Labels and title
    plt.xlabel('Month')
    plt.ylabel('Number of Contracts')
    plt.title(f'Contracts Published and Awarded in {year}')
    plt.legend()
    plt.grid(True)
    
    # Show the plot for the current year
    plt.show()
# Out:
# C:\Users\sobin\AppData\Local\Temp\ipykernel_14744\51448626.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   awarded_df['Awarded Date'] = awarded_df['Awarded Date'].fillna(awarded_df['Published Date'])

# %%
# Example strategy: Fill missing numeric values with 0 and categorical with 'Unknown'
df['Postcode'] = df['Postcode'].fillna('Unknown')
df['Value Low'] = df['Value Low'].fillna(0)
df['Value High'] = df['Value High'].fillna(0)

# %%
# Drop columns with excessive missing data if necessary (e.g., more than 50% missing)
df = df.dropna(thresh=len(df) * 0.5, axis=1)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Basic statistics
print(df.describe())

# Number of tenders by region
tenders_by_region = df['Region'].value_counts()
print("Tenders by Region:\n", tenders_by_region)

# Distribution of contract values
df['Value Low'] = pd.to_numeric(df['Value Low'], errors='coerce')
df['Value High'] = pd.to_numeric(df['Value High'], errors='coerce')

df[['Value Low', 'Value High']].hist(bins=50)
plt.show()
# Out:
#           Value Low    Value High  Awarded Value  Published Year  \
# count  1.723400e+04  1.723400e+04   1.406000e+04     17234.00000
# mean   1.465108e+08  1.973944e+07   2.485447e+07      2020.19537
# std    1.524439e+10  8.131064e+08   5.423735e+08         2.52346
# min    0.000000e+00  0.000000e+00   0.000000e+00      2015.00000
# 25%    2.570600e+04  0.000000e+00   4.045875e+04      2018.00000
# 50%    9.195942e+04  0.000000e+00   1.172160e+05      2021.00000
# 75%    4.717865e+05  1.179265e+04   5.097398e+05      2022.00000
# max    2.000000e+12  1.020000e+11   5.100000e+10      2024.00000
#
#        Published Month
# count     17234.000000
# mean          6.184751
# std           3.357997
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Tenders by Region:
#  Region
# Any region                                                                                                                                                                                                                                                                                                                                 11751
# United Kingdom                                                                                                                                                                                                                                                                                                                              3705
# Scotland                                                                                                                                                                                                                                                                                                                                     463
# United Kingdom,Isle of Man,Channel Islands,British Oversea Territories,Europe,Rest of the World                                                                                                                                                                                                                                              302
# United Kingdom,Isle of Man,Channel Islands                                                                                                                                                                                                                                                                                                   302
#                                                                                                                                                                                                                                                                                                                                            ...
# United Kingdom,Isle of Man,Channel Islands,Rest of the World                                                                                                                                                                                                                                                                                   1
# London,South East,South West,Scotland                                                                                                                                                                                                                                                                                                          1
# United Kingdom,Albania,Belgium,Bulgaria,Cyprus,Poland,Bahrain,Botswana,Brazil,Cameroon,Canada,Chile,China,Colombia,Congo (Democratic Republic),Egypt,Eswatini,Ghana,Hong Kong,India,Indonesia,Iran,Jordan,Kenya,Kuwait,Lebanon,Libya,Malawi,Mexico,Morocco,Nepal,Oman,Pakistan,Peru,Qatar,Rwanda,Saudi Arabia,Singapore,Sri Lanka,Syria        1
# North East,North West,Scotland                                                                                                                                                                                                                                                                                                                 1
# Any region,South East                                                                                                                                                                                                                                                                                                                          1
# Name: count, Length: 90, dtype: int64

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import numpy as np

# Convert the 'Published Date' column to datetime, handling mixed time zones
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Drop rows where 'Published Date' could not be converted
df = df.dropna(subset=['Published Date'])

# Extract the year from the 'Published Date' column
df['Year'] = df['Published Date'].dt.year

# Filter data to include only contracts from 2015 onwards
df = df[df['Year'] >= 2015]

# Group data by year and count the number of tenders per year
annual_data = df.groupby('Year').size()

# Adjust the count for 2024 based on the number of months available (8/12)
if 2024 in annual_data.index:
    annual_data[2024] = annual_data[2024] * (12 / 8)

# Find optimal ARIMA order
model = auto_arima(annual_data, seasonal=False)
model_fit = model.fit(annual_data)

# Predict the next 5 years
forecast, conf_int = model_fit.predict(n_periods=5, return_conf_int=True)

# Create forecast years
forecast_years = np.arange(annual_data.index[-1] + 1, annual_data.index[-1] + 6)

# Plot the historical data and the forecast
plt.figure(figsize=(12, 8))
plt.plot(annual_data.index, annual_data, label='Historical Data', color='steelblue', marker='o', linestyle='-')
plt.plot(forecast_years, forecast, label='Forecast', color='darkorange', linestyle='--', marker='x')

# Add confidence intervals
plt.fill_between(forecast_years, conf_int[:, 0], conf_int[:, 1], color='darkorange', alpha=0.3)

# Annotations and labels
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Tenders', fontsize=14)
plt.title('Forecast of Number of Tenders from 2015 for the Next 5 Years', fontsize=16)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(np.arange(min(annual_data.index), max(forecast_years) + 1, 1), rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sobin\miniforge3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd

# Convert 'Start Date' and 'End Date' to datetime, handling any errors
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', utc=True)
df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)

# Ensure 'Status' column is of type string
df['Status'] = df['Status'].astype(str)

# Count frameworks by type and region
framework_by_region = df.groupby(['Region', 'OJEU Contract Type']).size().unstack(fill_value=0)
print("Frameworks by Region and Type:\n", framework_by_region)

# For live and upcoming frameworks, filter based on date and status
current_year = pd.Timestamp.now().year

# Filter for live frameworks
live_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) & 
    (df['End Date'].notna()) &
    (df['Start Date'].dt.year <= current_year) &
    (df['End Date'].dt.year >= current_year)
]

# Filter for upcoming frameworks
upcoming_frameworks = df[
    (df['Status'] == 'Open') & 
    (df['Start Date'].notna()) &
    (df['Start Date'].dt.year > current_year)
]

print("Live Frameworks:\n", live_frameworks)
print("Upcoming Frameworks:\n", upcoming_frameworks)
# Out:
# Frameworks by Region and Type:
#  OJEU Contract Type                                  NotApplicable  \
# Region
# Any region                                                    247
# Any region,East Midlands,East of England                        0
# Any region,East Midlands,West Midlands                          0
# Any region,East of England                                      0
# Any region,London                                               0
# ...                                                           ...
# West Midlands,Scotland                                          0
# Yorkshire and The Humber,London,South East,Scot...              0
# Yorkshire and The Humber,Scotland                               0
# Yorkshire and The Humber,United Kingdom                         0
# Yorkshire and The Humber,West Midlands,South We...              1
#
# OJEU Contract Type                                  NotSpecified  Products  \
# Region
# Any region                                                   176      2816
# Any region,East Midlands,East of England                       0         0
# Any region,East Midlands,West Midlands                         0         0
# Any region,East of England                                     0         1
# Any region,London                                              0         3
# ...                                                          ...       ...
# West Midlands,Scotland                                         0         0
# Yorkshire and The Humber,London,South East,Scot...             0         0
# Yorkshire and The Humber,Scotland                              0         0
# Yorkshire and The Humber,United Kingdom                        0         0
# Yorkshire and The Humber,West Midlands,South We...             0         0
#
# OJEU Contract Type                                  Services  Works
# Region
# Any region                                              7981    119
# Any region,East Midlands,East of England                   1      0
# Any region,East Midlands,West Midlands                     3      0
# Any region,East of England                                 2      0
# Any region,London                                         31      0
# ...                                                      ...    ...
# West Midlands,Scotland                                     2      0
# Yorkshire and The Humber,London,South East,Scot...         1      0
# Yorkshire and The Humber,Scotland                          1      0
# Yorkshire and The Humber,United Kingdom                    1      0
# Yorkshire and The Humber,West Midlands,South We...         0      0
#
# [84 rows x 5 columns]
# Live Frameworks:
#                     Notice Identifier     Notice Type  \
# 1716                          RM6235        Contract
# 7062                          RM6235        Contract
# 7936           20240729203800-119413        Contract
# 7994                    BIP872421405        Contract
# 8082                   C24-0484-1922        Contract
# 8090                    BIP879601180        Contract
# 8103      STHOX001-DN735017-73889574        Contract
# 8108           tender_455196/1386728        Contract
# 8122           tender_440638/1374739        Contract
# 8281                         376E_24        Contract
# 8361           tender_435626/1393676        Contract
# 8369                        2024-717        Contract
# 8433     CHEAST001-DN736854-10873064        Contract
# 8438           tender_446106/1392530        Contract
# 8445      GOSPT001-DN736351-02296027        Contract
# 8448       AHSN001-DN670401-77820277  PreProcurement
# 8452                      YFFIE00124        Contract
# 8464            20240731180746-72814        Contract
# 8468      GOSPT001-DN735694-96897808        Contract
# 8480       MANC001-DN734747-03973553        Contract
# 8500       AHSN001-DN670401-69684874  PreProcurement
# 8501       AHSN001-DN670401-43079167  PreProcurement
# 8502       GREENCH-DN733527-02777469        Contract
# 8510       GREENCH-DN733245-82283485        Contract
# 8624                  FCTRFQ03/24-01        Pipeline
# 15949  NPSBARNS001-DN536468-59820066        Pipeline
#
#                                      Organisation Name Status  \
# 1716                          Crown Commercial Service   Open
# 7062                          Crown Commercial Service   Open
# 7936                      Hyde Housing Association Ltd   Open
# 7994                                   British Library   Open
# 8082                                   JNCC SUPPORT CO   Open
# 8090                  The Corporation of Trinity House   Open
# 8103                South Oxfordshire District Council   Open
# 8108        The British Broadcasting Corporation (BBC)   Open
Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7062   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7936   It is Hyde's intention to create a framework a...  Unknown
# 7994   The British Library is seeking suppliers for t...  Unknown
# 8082   The programme recruits and trains volunteers t...  Unknown
# 8090       T0542 - Tender for Agile Consultancy Services  Unknown
# 8103   Aims\r\nTo set up and deliver an enterprise su...  Unknown
# 8108   The BBC is seeking to procure a cloud-based sa...  Unknown
# 8122   The BBC requires a Data Catalogue.\r\n\r\nThis...  Unknown
# 8281   This REPLACES the previous Prior Information N...  Unknown
# 8361   An Invitation to Tender for a contract with th...  Unknown
# 8369   FARM ENVIRONMENT DATA EXPERTISE SUPPORT\r\nAHD...  Unknown
# 8433   CONTRACT FOR THE PROVISION OF  ONLINE PLANNING...  Unknown
# 8438   This requirement is focused on the delivery of...  Unknown
# 8445   Gosport Borough Council are looking for Contra...  Unknown
# 8448   Repurposing devices through either recycling o...  Unknown
# 8452   As a What Works Centre that wants to drive cha...  Unknown
# 8464   The UKAEA has a requirement for a Computerised...  Unknown
# 8468   Gosport Borough Council (GBC) is inviting quot...  Unknown
# 8480   Manchester City Council seeks to a Market Admi...  Unknown
# 8500   The purpose of this PIN is to inform market op...  Unknown
# 8501   The purpose of this PIN is to inform market op...  Unknown
# 8502   Eastlight currently uses Keystone for asset ma...  Unknown
# 8510   Eastlight currently uses Keystone for asset ma...  Unknown
# 8624   This is a Prior Information Notice where the t...  Unknown
# 15949  To consolidate the contracts in the management...  Unknown
#
#                Region                                          Cpv Codes  ...  \
# 1716   United Kingdom  32210000 32412100 32510000 32530000 38115100 3...  ...
# 7062   United Kingdom  32210000 32412100 32510000 32530000 38115100 3...  ...
# 7936       Any region  66171000 71241000 71242000 71244000 72224000 7...  ...
# 7994       Any region                                          72212321   ...
# 8082   United Kingdom      72224000 73000000 79000000 92000000 98000000   ...
# 8090       Any region                                 79410000 72224000   ...
# 8103   United Kingdom                        72221000 79000000 80500000   ...
# 8108       Any region                                          72268000   ...
# 8122       Any region                                          72322000   ...
# 8281   United Kingdom      22110000 22200000 48160000 79980000 92511000   ...
# 8361       Any region                                          72300000   ...
# 8369   United Kingdom                        72300000 77100000 90714100   ...
# 8433   United Kingdom                                          48000000   ...
# 8438       Any region                                          48000000   ...
# 8445   United Kingdom                                          72000000   ...
# 8448   United Kingdom                                 30000000 72000000   ...
# 8452   United Kingdom                                 48000000 72000000   ...
# 8464       Any region      48000000 48100000 48420000 48421000 48422000   ...
# 8468   United Kingdom                                          48000000   ...
# 8480   United Kingdom                                 48000000 72260000   ...
# 8500   United Kingdom                                 30000000 72000000   ...
# 8501   United Kingdom                                 30000000 72000000   ...
# 8502   United Kingdom                                          72000000   ...
# 8510   United Kingdom                                          72000000   ...
# 8624   United Kingdom                                 48000000 72000000   ...
# 15949  United Kingdom                                 48000000 72000000   ...
#
#         Value High Awarded Value  \
# 1716           0.0           NaN
# 7062           0.0           NaN
# 7936   360000000.0           NaN
# 7994           0.0           NaN
# 8082           0.0           NaN
# 8090      500000.0           NaN
# 8103       50000.0           NaN
# 8108     1000000.0           NaN
# 8122           0.0           NaN
# 8281           0.0           NaN
# 8361      200000.0           NaN
# 8369           0.0           NaN
# 8433      100000.0           NaN
# 8438           0.0           NaN
# 8445      364100.0           NaN
# 8448     3000000.0           NaN
# 8452      200000.0           NaN
# 8464     4080000.0           NaN
# 8468       40000.0           NaN
# 8480      450000.0           NaN
# 8500     3000000.0           NaN
# 8501     3000000.0           NaN
# 8502      351000.0           NaN
# 8510      351000.0           NaN
# 8624           0.0           NaN
# 15949      48622.0           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 1716                                                 NaN
# 7062                                                 NaN
# 7936                                                 NaN
# 7994                                                 NaN
# 8082                                                 NaN
# 8090                                                 NaN
# 8103                                                 NaN
# 8108                                                 NaN
# 8122                                                 NaN
# 8281                                                 NaN
# 8361                                                 NaN
# 8369                                                 NaN
# 8433                                                 NaN
# 8438                                                 NaN
# 8445                                                 NaN
# 8448                                                 NaN
# 8452                                                 NaN
# 8464                                                 NaN
# 8468                                                 NaN
# 8480                                                 NaN
# 8500                                                 NaN
# 8501                                                 NaN
# 8502                                                 NaN
# 8510                                                 NaN
# 8624                                                 NaN
# 15949                                                NaN
#
#       Contract start date Contract end date OJEU Procedure Type Closing Time  \
# 1716                  NaN               NaN     RestrictedOJEU         11:59
# 7062                  NaN               NaN     RestrictedOJEU         11:59
# 7936                  NaN               NaN               Open         12:00
# 7994                  NaN               NaN               Open         00:00
# 8082                  NaN               NaN        OpenNonOJEU         16:00
# 8090                  NaN               NaN               Open         12:00
# 8103                  NaN               NaN        OpenNonOJEU         17:00
# 8108                  NaN               NaN           OpenOJEU         12:00
# 8122                  NaN               NaN           OpenOJEU         10:00
# 8281                  NaN               NaN           OpenOJEU         12:00
# 8361                  NaN               NaN           OpenOJEU         17:00
# 8369                  NaN               NaN        OpenNonOJEU         12:00
# 8433                  NaN               NaN        OpenNonOJEU         12:00
# 8438                  NaN               NaN           OpenOJEU         14:00
# 8445                  NaN               NaN           OpenOJEU         12:00
# 8448                  NaN               NaN                              NaN
# 8452                  NaN               NaN        OpenNonOJEU         18:00
# 8464                  NaN               NaN         Restricted         12:00
# 8468                  NaN               NaN        OpenNonOJEU         12:00
# 8480                  NaN               NaN           OpenOJEU         11:00
# 8500                  NaN               NaN                              NaN
# 8501                  NaN               NaN                              NaN
# 8502                  NaN               NaN     RestrictedOJEU         12:00
# 8510                  NaN               NaN     RestrictedOJEU         12:00
# 8624                  NaN               NaN           OpenOJEU           NaN
# 15949                 NaN               NaN                              NaN
#
#       Published Year Published Month  Year
# 1716            2021               9  2021
# 7062            2021               9  2021
# 7936            2024               7  2024
# 7994            2024               7  2024
# 8082            2024               7  2024
# 8090            2024               8  2024
# 8103            2024               7  2024
# 8108            2024               7  2024
# 8122            2024               7  2024
# 8281            2024               7  2024
# 8361            2024               8  2024
# 8369            2024               7  2024
# 8433            2024               8  2024
# 8438            2024               8  2024
# 8445            2024               8  2024
# 8448            2024               8  2024
# 8452            2024               8  2024
# 8464            2024               7  2024
# 8468            2024               7  2024
# 8480            2024               7  2024
# 8500            2024               7  2024
# 8501            2024               7  2024
# 8502            2024               7  2024
# 8510            2024               7  2024
# 8624            2024               4  2024
# 15949           2021               4  2021
#
# [26 rows x 35 columns]
# Upcoming Frameworks:
#                                        Notice Identifier Notice Type  \
# 845                                              RM6124    Contract
# 1993                                             RM6126    Contract
# 2134                                            RM6242.    Contract
# 3028   Automation Marketplace Dynamic Purchasing System    Contract
# 3854                                      CIMPLE-237688    Contract
# 3960                                            RM6242.    Contract
# 4008                         EPAS17 (EPL - 2015 - 0032)    Contract
# 4251                                             RM6322    Contract
# 4256                                             RM6264    Contract
# 4689                                        RM3764.iii.    Contract
# 4758                                            RM3825.    Contract
# 5555                                             RM6126    Contract
# 5997                                      CIMPLE-237688    Contract
# 6086                                             RM6343    Pipeline
# 6110                                           RM6200..    Contract
# 6112                                             RM6264    Contract
# 6265                                             RM6353    Pipeline
# 6496                                           RM6148..    Contract
# 6518                                             RM6295    Pipeline
# 6756                                      CIMPLE-339612    Contract
# 6869                                             RM6190    Pipeline
# 7064                                             RM6322    Contract
# 7066                                             RM6354    Pipeline
# 7351                                             RM6353    Pipeline
# 7509                           YPO001-DN433526-71875119    Contract
# 7602                                             RM6365    Pipeline
# 7809                                             RM6095    Contract
# 7903                                             RM6343    Pipeline
# 7910                                             RM6346    Pipeline
# 7912                                             158_25    Contract
# 7917                                            RM6302.    Pipeline
# 7923                                             RM6364    Pipeline
# 7925                                           RM6200..    Contract
# 7932                                             RM6124    Contract
# 7938                                             RM6356    Pipeline
# 8155                              tender_442882/1365677    Pipeline
# 8358                                        RM3764.iii.    Contract
# 8432                                             664_25    Contract
# 8485                                             RM6285    Contract
# 8503                           ECC001-DN706093-33619574    Contract
# 8516   Automation Marketplace Dynamic Purchasing System    Contract
# 8517                                            RM3825.    Contract
# 8628                              tender_399335/1303281    Contract
# 8646                                             RM6213    Contract
# 8665                                            RM6361.    Pipeline
# 8685                                             RM6366    Pipeline
# 12024                        EPAS17 (EPL - 2015 - 0032)    Contract
# 13018                                            RM6095    Contract
# 13811                          YPO001-DN433526-71875119    Contract
# 13875                                            RM6213    Contract
# 14923                              20201016093029-30310    Contract
# 15473                          YPO001-DN517178-18851510    Contract
#
#                                       Organisation Name Status  \
# 845                            Crown Commercial Service   Open
# 1993                           Crown Commercial Service   Open
# 2134                           Crown Commercial Service   Open
# 3028                           Crown Commercial Service   Open
# 3854          Bishop Wilkinson Catholic Education Trust   Open
# 3960                           Crown Commercial Service   Open
# 4008                        EASTERN PROCUREMENT LIMITED   Open
# 4251                           Crown Commercial Service   Open
# 4256                           Crown Commercial Service   Open
# 4689                           Crown Commercial Service   Open
# 4758                           Crown Commercial Service   Open
# 5555                           Crown Commercial Service   Open
# 5997          Bishop Wilkinson Catholic Education Trust   Open
# 6086                           Crown Commercial Service   Open
# 6110                           Crown Commercial Service   Open
# 6112                           Crown Commercial Service   Open
# 6265                           Crown Commercial Service   Open
# 6496                           Crown Commercial Service   Open
# 6518                           Crown Commercial Service   Open
# 6756                              HEART ACADEMIES TRUST   Open
# 8665  2024-05-22 14:50:29+00:00
# 8685  2024-05-16 13:43:24+00:00
# 12024 2019-04-18 13:06:25+00:00
# 13018 2019-10-21 08:48:11+00:00
# 13811 2020-01-28 15:13:55+00:00
# 13875 2020-04-10 12:28:04+00:00
# 14923 2020-10-16 08:30:32+00:00
# 15473 2021-04-08 08:23:59+00:00
#
#                                                    Title  \
# 845                           Communications Marketplace
# 1993                           Research and Insights DPS
# 2134              Construction Professional Services DPS
# 3028                                              RM6173
# 3854   A DPS for sustainable and ethically sourced go...
# 3960              Construction Professional Services DPS
# 4008        DPS - Dynamic Supplier List: Asset Solutions
# 4251     Fund Administration & Disbursement Services DPS
# 4256      Facilities Management & Workplace Services DPS
# 4689                           Cyber Security Services 3
# 4758   Health and Social Care Network (HSCN) Access S...
# 5555                           Research and Insights DPS
# 5997   A DPS for sustainable and ethically sourced go...
# 6086                        Estate Management Services 2
# 6110                         Artificial Intelligence DPS
# 6112      Facilities Management & Workplace Services DPS
# 6265                           Tyres, Glass & Telematics
# 6496   Quality Assurance and Testing for IT Systems 2...
# 6518                                 Outsourced Services
# 6756   Dynamic Purchasing System (DPS) for the provis...
# 6869                               Technology Services 4
# 7064     Fund Administration & Disbursement Services DPS
# 7066   Courier, Distribution, Storage and Specialist ...
# 7351                           Tyres, Glass & Telematics
# 7509   YPO - 000999 Training for The Emergency Servic...
# 7602   Pre-Market Engagement for RM1043.8 Digital Out...
# 7809              Gigabit Capable Connectivity Extension
# 7903                        Estate Management Services 2
# 7910   Records Information Management, Digital Soluti...
# 7912   158_25 Paints, Chalks, Crayons and other Art-R...
# 7917                                   Language Services
# 7923                           Media & Creative Services
# 7925                         Artificial Intelligence DPS
# 7932                          Communications Marketplace
# 7938                Construction Professional Services 2
# 8155                 Application Development and Support
# 8358                           Cyber Security Services 3
# 8432                         664_25 Consultancy Services
# 8485                             Back Office Software 2.
# 8503                     CO0437 - Data Management System
# 8516                                              RM6173
# 8517   Health and Social Care Network (HSCN) Access S...
# 8628   VOLUNTARY TRANSPARENCY NOTICE: MODE 5 IDENTIFI...
# 8646     Vehicle Charging Infrastructure Solutions (DPS)
# 8665   Multifunctional Devices (MFDs), Print, Digital...
# 8685                          Debt Resolution Services 2
# 12024       DPS - Dynamic Supplier List: Asset Solutions
# 13018             Gigabit Capable Connectivity Extension
# 13811  YPO - 000999 Training for The Emergency Servic...
# 13875    Vehicle Charging Infrastructure Solutions (DPS)
# 14923  National Agreement for the Provision of Digita...
# 15473      YPO - 001056 Metering and Meter Data Services
#
#                                              Description Postcode  \
# 845    The Communications Marketplace DPS Agreement w...  Unknown
# 1993   Crown Commercial Service (CCS) as the authorit...  Unknown
# 2134   The RM6242 DPS will be organised into distinct...  Unknown
# 3028   Automation services including the design, buil...  Unknown
# 3854   Bishop Wilkinson Catholic Education Trust (BWC...  Unknown
# 3960   The RM6242 DPS will be organised into distinct...  Unknown
# 4008   Dear Contractor Thank you for your interest in...  Unknown
# 4251   Crown Commercial Service (CCS), as the Authori...  Unknown
# 4256   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 4689   Crown Commercial Service (CCS) has set up a dy...  Unknown
# 4758   Crown Commercial Service (the Authority) has p...  Unknown
# 5555   Crown Commercial Service (CCS) as the authorit...  Unknown
# 5997   Bishop Wilkinson Catholic Education Trust (BWC...  Unknown
# 6086   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 6110   Crown Commercial Service has set up a Dynamic ...  Unknown
# 6112   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 6265   Crown Commercial Service, as the Authority,  i...  Unknown
# 6496   Crown Commercial Service (CCS) is setting up a...  Unknown
# 6518   Crown Commercial Service, as the Authority, in...  Unknown
# 6756   HEART Academies Trust (HEART) are seeking to e...  Unknown
# 6869   Crown Commercial Service, as the Authority, in...  Unknown
# 7064   Crown Commercial Service (CCS), as the Authori...  Unknown
# 7066   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7351   Crown Commercial Service, as the Authority,  i...  Unknown
# 7509   YPO are looking for Suppliers to be appointed ...  Unknown
# 7602   Crown Commercial Service intends to hold marke...  Unknown
# 7809   Crown Commercial Service (CCS) set up a Dynami...  Unknown
# 7903   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 7910   Crown Commercial Service (CCS) acting as the A...  Unknown
# 7912   The supply of paints, chalks crayons and other...  Unknown
# 7917   Crown Commercial Service, as the Authority, in...  Unknown
# 7923   The Marketing & Communications Category (Marco...  Unknown
# 7925   Crown Commercial Service has set up a Dynamic ...  Unknown
# 7932   The Communications Marketplace DPS Agreement w...  Unknown
# 7938   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 8155   The Specialist EOD, Exploitation and Counter M...  Unknown
# 8358   Crown Commercial Service (CCS) has set up a dy...  Unknown
# 8432   ESPO on behalf of ESPO and YPO are seeking to ...  Unknown
# 8485   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 8503   Essex County Council (ECC) currently uses a Da...  Unknown
# 8516   Automation services including the design, buil...  Unknown
# 8517   Crown Commercial Service (the Authority) has p...  Unknown
# 8628   VOLUNTARY TRANSPARENCY NOTICE (VTN) TO PLACE A...  Unknown
# 8646   CCS has a dynamic purchasing system for Vehicl...  Unknown
# 8665   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 8685   Crown Commercial Service (CCS) as the Authorit...  Unknown
# 12024  Dear Contractor Thank you for your interest in...  Unknown
# 13018  Crown Commercial Service (CCS) set up a Dynami...  Unknown
# 13811  YPO are looking for Suppliers to be appointed ...  Unknown
# 13875  CCS has a dynamic purchasing system for Vehicl...  Unknown
# 14923  The Forensic Capability Network (FCN - the Aut...  Unknown
# 15473  YPO are looking for Suppliers to be appointed ...  Unknown
#
#                                                   Region  \
# 845    United Kingdom,Belgium,Denmark,Estonia,Finland...
# 1993                                      United Kingdom
# 2134                                      United Kingdom
# 3028                                      United Kingdom
# 3854                                          Any region
# 3960                                      United Kingdom
# 4008   United Kingdom,Isle of Man,Channel Islands,Bri...
# 4251                                      United Kingdom
# 4256                                      United Kingdom
# 4689                                      United Kingdom
# 4758                                      United Kingdom
# 5555                                      United Kingdom
# 5997                                          Any region
# 6086                                      United Kingdom
# 6110                                      United Kingdom
# 6112                                      United Kingdom
# 6265                                      United Kingdom
# 6496                                      United Kingdom
# 6518                                      United Kingdom
# 6756                                          Any region
# 6869                                      United Kingdom
# 7064                                      United Kingdom
# 7066                                      United Kingdom
# 7351                                      United Kingdom
# 7509                                      United Kingdom
# 7602                                      United Kingdom
# 7809   United Kingdom,Isle of Man,Channel Islands,Bri...
# 7903                                      United Kingdom
# 7910                                      United Kingdom
# 8485                                  48000000 72000000   ...          0.0
# 8503                                  72000000 72220000   ...          0.0
# 8516                                           72000000   ...          0.0
# 8517   32000000 48510000 48760000 50334400 51300000 6...  ...          0.0
# 8628                                  32000000 50000000   ...   16000000.0
# 8646   09310000 09331000 14213200 24111600 30162000 3...  ...          0.0
# 8665   30100000 30232100 30232130 48000000 50300000 7...  ...          0.0
# 8685   48440000 66170000 71621000 72000000 73000000 7...  ...          0.0
# 12024  03419000 14630000 24963000 31300000 31680000 3...  ...          0.0
# 13018                                          32000000   ...          0.0
# 13811  34962230 35112100 38910000 38970000 39162200 4...  ...  200000000.0
# 13875  09310000 09331000 14213200 24111600 30162000 3...  ...          0.0
# 14923  60000000 64120000 71600000 71610000 71620000 7...  ...   60000000.0
# 15473                                 65000000 72314000   ...   10000000.0
#
#       Awarded Value  \
# 845             NaN
# 1993            NaN
# 2134            NaN
# 3028            NaN
# 3854            NaN
# 3960            NaN
# 4008            NaN
# 4251            NaN
# 4256            NaN
# 4689            NaN
# 4758            NaN
# 5555            NaN
# 5997            NaN
# 6086            NaN
# 6110            NaN
# 6112            NaN
# 6265            NaN
# 6496            NaN
# 6518            NaN
# 6756            NaN
# 6869            NaN
# 7064            NaN
# 7066            NaN
# 7351            NaN
# 7509            NaN
# 7602            NaN
# 7809            NaN
# 7903            NaN
# 7910            NaN
# 7912            NaN
# 7917            NaN
# 7923            NaN
# 7925            NaN
# 7932            NaN
# 7938            NaN
# 8155            NaN
# 8358            NaN
# 8432            NaN
# 8485            NaN
# 8503            NaN
# 8516            NaN
# 8517            NaN
# 8628            NaN
# 8646            NaN
# 8665            NaN
# 8685            NaN
# 12024           NaN
# 13018           NaN
# 13811           NaN
# 13875           NaN
# 14923           NaN
# 15473           NaN
#
#       Supplier [Name|Address|Ref type|Ref Number|Is SME|Is VCSE]  \
# 845                                                  NaN
# 1993                                                 NaN
# 2134                                                 NaN
# 3028                                                 NaN
# 3854                                                 NaN
# 3960                                                 NaN
# 4008                                                 NaN
# 4251                                                 NaN
# 4256                                                 NaN
# 4689                                                 NaN
# 4758                                                 NaN
# 5555                                                 NaN
# 5997                                                 NaN
# 6086                                                 NaN
# 6110                                                 NaN
# 6112                                                 NaN
# 6265                                                 NaN
# 6496                                                 NaN
# 6518                                                 NaN
# 6756                                                 NaN
# 6869                                                 NaN
# 7064                                                 NaN
# 7066                                                 NaN
# 7351                                                 NaN
# 7509                                                 NaN
# 7602                                                 NaN
# 7809                                                 NaN
# 7903                                                 NaN
# 7910                                                 NaN
# 7912                                                 NaN
# 7917                                                 NaN
# 7923                                                 NaN
# 7925                                                 NaN
# 7932                                                 NaN
# 7938                                                 NaN
# 8155                                                 NaN
# 8358                                                 NaN
# 8432                                                 NaN
# 8485                                                 NaN
# 8503                                                 NaN
# 8516                                                 NaN
# 8517                                                 NaN
# 8628                                                 NaN
# 8646                                                 NaN
# 8665                                                 NaN
# 8685                                                 NaN
# 12024                                                NaN
# 13018                                                NaN
# 13811                                                NaN
# 13875                                                NaN
# 14923                                                NaN
# 15473                                                NaN
#
#       Contract start date Contract end date         OJEU Procedure Type  \
# 6869           NaN           2023               8  2023
# 7064         00:00           2022              11  2022
# 7066           NaN           2024               1  2024
# 7351           NaN           2023               9  2023
# 7509         23:59           2020               1  2020
# 7602           NaN           2024               3  2024
# 7809         23:59           2019              10  2019
# 7903           NaN           2023               9  2023
# 7910           NaN           2024               7  2024
# 7912         12:00           2024               7  2024
# 7917           NaN           2024               7  2024
# 7923           NaN           2024               6  2024
# 7925         23:59           2023              11  2023
# 7932         00:00           2021               8  2021
# 7938           NaN           2024               5  2024
# 8155           NaN           2024               6  2024
# 8358         00:00           2022              12  2022
# 8432         12:00           2024               8  2024
# 8485         15:00           2024               7  2024
# 8503         12:00           2024               7  2024
# 8516         00:00           2022               4  2022
# 8517         00:00           2023               1  2023
# 8628         12:00           2024               6  2024
# 8646         00:00           2020               4  2020
# 8665           NaN           2024               5  2024
# 8685           NaN           2024               5  2024
# 12024        12:00           2019               4  2019
# 13018        23:59           2019              10  2019
# 13811        23:59           2020               1  2020
# 13875        00:00           2020               4  2020
# 14923        12:00           2020              10  2020
# 15473        01:59           2021               4  2021
#
# [52 rows x 35 columns]
# C:\Users\sobin\AppData\Local\Temp\ipykernel_14744\1426416616.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', utc=True)
# C:\Users\sobin\AppData\Local\Temp\ipykernel_14744\1426416616.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', utc=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame already loaded and processed

# Convert 'Published Date' to datetime if not already done
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce', utc=True)

# Filter for contracts from 2015 onwards
df = df[df['Published Date'].dt.year >= 2015]

# Convert 'Suitable for SME' and 'Suitable for VCO' to strings, then to boolean
df['Suitable for SME'] = df['Suitable for SME'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')
df['Suitable for VCO'] = df['Suitable for VCO'].astype(str).str.strip().str.lower().fillna('no').apply(lambda x: x == 'yes')

# Add columns for the year
df['Published Year'] = df['Published Date'].dt.year

# Group by year and calculate the number of suitable contracts for SMEs and VCOs
yearly_sme_vco = df.groupby('Published Year').agg(
    Suitable_SME_Count=('Suitable for SME', 'sum'),
    Suitable_VCO_Count=('Suitable for VCO', 'sum')
).reset_index()

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_SME_Count'], marker='o', label='Suitable for SME')
plt.plot(yearly_sme_vco['Published Year'], yearly_sme_vco['Suitable_VCO_Count'], marker='x', label='Suitable for VCO')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Contracts')
plt.title('Number of Contracts Suitable for SMEs and VCOs (Yearly)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Print the results (as requested in the initial code)
total_contracts = df.shape[0]
suitable_for_sme = df['Suitable for SME'].sum()
suitable_for_vco = df['Suitable for VCO'].sum()
suitable_for_sme_percentage = (suitable_for_sme / total_contracts) * 100
suitable_for_vco_percentage = (suitable_for_vco / total_contracts) * 100

print(f'Percentage of contracts suitable for SMEs: {suitable_for_sme_percentage:.2f}%')
print(f'Percentage of contracts suitable for VCOs: {suitable_for_vco_percentage:.2f}%')
# Out:
# Percentage of contracts suitable for SMEs: 68.02%
# Percentage of contracts suitable for VCOs: 19.36%
